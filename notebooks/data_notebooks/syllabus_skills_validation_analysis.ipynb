# %% [markdown]
# ## Text as Skills Syllabi Validation
#
# This notebook validates that text can be used as a proxy for skills.

# %%
from json import JSONDecoder, JSONDecodeError
import re
import os
from collections import Counter
from datetime import datetime

# %%
maybe = ["service", "administration", 'process']

# %%
my_stop_words = ['papers', 'paper', 'discussion', 'complete', 'require', 'time', 'quiz', 'attendance',
 'study', 'instructor', 'examination', 'course', 'student', 'students', 'syllabus', 'work', 'class', 'assignment',
 'requiring', 'requirement', 'credit', 'include', 'grade', 'week', 'professor', 'exam', 'final', 'credits', 'essay',
 'assessment', '•', 'prerequisite', 'book', 'textbook', 'withdraw', 'homework', 'hyperlink',
 'mailto:', 'exercise', '%', 'drop', 'withdrawl', 'pass', 'fail', 'classroom','campus','catalog',
 'unit', 'chapter', 'sunday', 'monday', 'tuesday', 'wednesday','thursday','friday','saturday','january',
 'february', 'march', 'april', 'may', 'june','july', 'august','september','october','november','december',
 'project','participation','semeseter', 'trimester','quarter','academic',
 'point', 'provide','activity', 'learn','date','office','hour','page', 'lecture',
 'review','lesson','disability','contact','meeting','meet','deadline','submit','integrity','dishonesty',
    'plagiarism', 'able', 'prepare', 'response', 'study', 'department',
 'cheat','report','submit','faculty','university','semester','presentation', 'summer','practicum',
 'instruction', 'generally', 'site', 'description', 'detail', 'unpaid', 'involve', 'college',
 'group', 'problem', 'support', 'section', 'schedule', 'available', 'term', 'late',
 'email', 'system', 'and/or','absence', 'introduction', 'write', 'read', 'test', 
 'topic', 'need', 'online','skill','note','resource', 'expect', 'post',  'question', 'material', 'follow',
 'help', 'apply', 'receive', 'base','practice','school','issue', 'center',
 'fall', 'assign', 'general', 'outcome', 'find', 'basic', 'total', 'evaluation', 'give', 'text',
 'learn', 'grade', 'require', 'point', 'hour', 'include', 'follow',
  'question', 'service', 'provide', 'course', 'requirement', 'exam', 'individual', 'expect', 
 'reading', 'give', 'access', 'experience', 'relate', 'discuss', 'activity', 'major',
    'result', 'level', 'form', 'appropriate', 'complete', 'assign', 'class','present', 'accommodation',
 'issue', 'well', 'think', 'list', 'phone', 'understand',  
    'quiz', 'miss', 'problem', 'right', 'degree', 'begin', 'teach', 'conduct', 'take', 'additional' 
    ]

# %%
NOT_WHITESPACE = re.compile(r'[^\s]')
def decode_stacked(document, pos=0, decoder=JSONDecoder()):
    while True:
        match = NOT_WHITESPACE.search(document, pos)
        if not match:
            return
        pos = match.start()

        try:
            obj, pos = decoder.raw_decode(document, pos)
        except JSONDecodeError:
            # do something sensible if there's some error
            raise
        yield obj

# %%
i = 0

# %%
field_texts  = {}

# %%
import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
for stopword in my_stop_words:
    lexeme = nlp.vocab[stopword]
    lexeme.is_stop = True

# %%
import logging
logger = logging.getLogger("spacy")
logger.setLevel(logging.ERROR)

# %%
def clean_text(text, max_len=1500000):
    nlp.max_length = max_len
    if len(text) > max_len:
        text = text[0:max_len]
    doc = nlp(text.lower(), disable=["parser", "tagger", "ner"])
    clean_text = []
    for w in doc:
        if (not '\n' in w.text and not w.is_stop and not w.is_punct and not w.like_num and not '’' in w.text 
            and not ')' in w.text and not '\xa0' in w.text and not '\r' in w.text and not '\t' in w.text 
            and not '\v' in w.text and len(w.text) > 3 and "@" not in w.text and "https" not in w.text
            and w.lemma_ not in my_stop_words):
                # we add the lematized version of the word
                clean_text.append(w.lemma_)
    return clean_text

# %%
for filename in os.listdir("../openSyReal_part/"):
    i += 1
    if i > 3:
        break
    if filename.endswith(".json"): #Added try before countrycode and encoding argument
        with open("../openSyReal_part/" + filename, encoding = 'utf-8') as f:
            for line in f:
                for jsonfile in decode_stacked(line):
                    try:
                        if jsonfile['grid_country_code'] == 'US':
                            try:
                                field = jsonfile['field_name']
                                if field not in field_texts:
                                    field_texts[field] = []
                                if field in field_texts:
                                    field_texts[field].append(clean_text(jsonfile['text']))
                            except KeyError:
                                pass
                    except:
                        pass

# %%
field_texts.keys()
# Out:
# dict_keys(['Chemistry.', 'Speech Communication and Rhetoric.', 'Dentistry', 'Marketing.', 'Economics.', 'Business, Management, and Related Support Services.', 'Mathematics/Applied Mathematics', 'Spanish Language and Literature.', 'Engineering.', 'Health and Medical Administrative Services.', 'Political Science, Government, International Relations and National Security Studies.', 'Biological and Biomedical Sciences, General/Other.', 'Rhetoric and Composition/Writing Studies.', 'English Language and Literature/Letters', 'Mechanic and Repair Technologies/Technicians.', 'Psychology, General/Other.', 'Communications and Media Studies, General/Other.', 'Computer, Network, and Technology Support Services.', 'Film/Video and Photographic Arts.', 'Journalism.', 'History.', 'Parks, Recreation, Leisure, and Fitness Studies.', 'Chinese Language and Literature.', 'Allied Health Diagnostic, Intervention, and Treatment Professions.', 'Engineering Technologies and Engineering-related Fields.', 'Basic Computer Skills.', 'Social Work.', 'Philosophy.', 'Education.', 'Design and Applied Arts.', 'Geography and Cartography.', 'Anthropology.', 'Computer and Information Sciences.', 'Library Science.', 'Fine and Studio Arts.', "Women's Studies.", 'Music.', 'Sociology', 'Nursing', 'Legal Professions and Studies.', 'Theology and Religious Vocations.', 'Area, Ethnic, Cultural, Gender, and Group Studies, Other.', 'Anatomy.', 'Communication Disorders Sciences and Services.', 'Job-Seeking and Career Skills', 'Homeland Security.', 'Culinary Arts and Related Services.', 'Statistics.', 'Criminal Justice and Corrections.', 'Fire Protection.', 'Physics.', 'Geological and Earth Sciences/Geosciences.', 'Liberal Arts and Sciences, General Studies and Humanities.', 'Accounting and Related Services.', 'American Sign Language.', 'Basic Skills and Developmental/Remedial/High School Level Education', 'Drama/Theatre Arts and Stagecraft.', 'Construction Trades.', 'Natural Resources and Conservation.', 'Dance.', 'Linguistics.', 'Agriculture, Agriculture Operations, and Related Sciences.', 'Criminology.', 'Clinical, Counseling and Applied Psychology.', 'Second Language Learning.', 'Pharmacy, Pharmaceutical Sciences, and Administration.', 'Classics and Classical Languages, Literatures, and Linguistics.', 'Architecture and Related Services.', 'Atmospheric Sciences and Meteorology.', 'German Language and Literature.', 'French Language and Literature.', 'Astronomy and Astrophysics.', 'Interpersonal and Social Skills.', 'Medicine and Health Professions, General', 'Public Health.', 'Foods, Nutrition, and Related Services.', 'Religion/Religious Studies.', 'Cosmetology and Related Personal Grooming Services.', 'Military Science, Leadership, Operational Art, Applied Science, and Technologies', 'Archeology.', 'Research and Experimental Psychology.', 'Veterinary Medicine and Sciences', 'Family and Consumer Sciences/Human Sciences.', 'Japanese Language and Literature.', 'Health-related Knowledge and Skills.', 'Social Psychology.', 'Precision Production.', 'Hebrew Language and Literature.', 'Transportation and Materials Moving.'])

# %%
len(field_texts)
# Out:
# 89

# %%
field_texts['Chemistry.']
# Out:
# [['tentative',
#   'chem',
#   'interactive',
#   'notes',
#   'files',
#   '.doc',
#   '.pdf',
#   'format',
#   'print',
#   'notes',
#   'home',
#   'library',
#   'cyber',
#   'café',
#   'small',
#   'charge',
#   'computer',
#   'labs',
#   'download',
#   'handouts',
#   'ahead',
#   'scheduled',
#   'covered',
#   'notes',
#   'covered',
#   'sure',
#   'check',
#   'updates',
#   'interactive',
#   'notes',
#   'prior',
#   'coming',
#   'icons',
#   'icons',
#   'embedded',
#   'notes',
#   'symbols',
#   'alert',
#   'following',
#   'represents',
#   'fact',
#   'piece',
#   'information',
#   'definitions',
#   'element',
#   'compound',
#   'represents',
#   'useful',
#   'trick',
#   'likely',
#   'useful',
#   'convert',
#   'grams',
#   'moles',
#   'substance',
#   'alerts',
#   'important',
#   'relationship',
#   'micro',
#   'macro',
#   'scale',
#   'properties',
#   'phenomena',
#   'respect',
#   'provides',
#   'link',
#   'interesting',
#   'briefly',
#   'discussed',
#   'supplemental',
#   'scope',
#   'chemistry102',
#   'notes',
#   'chem',
#   'packets',
#   'listed',
#   'plus',
#   'exams',
#   'periodic',
#   'table',
#   'combined',
#   'downloadable',
#   'file',
#   '.docx',
#   '.pdf',
#   'version',
#   'beginning',
#   'downloads',
#   '.pdf',
#   'files',
#   'added',
#   'notes',
#   '.doc',
#   'word',
#   'files',
#   '.pdf',
#   'adobe',
#   'files',
#   'chemistry',
#   'topics',
#   'properties',
#   'solutions',
#   'chemistry',
#   'topics',
#   'properties',
#   'solutions',
#   'introductory',
#   'notes',
#   'notes',
#   'provided',
#   'download',
#   'periodic',
#   'table',
#   'chemical',
#   'kinetics',
#   'chemical',
#   'kinetics',
#   'chemical',
#   'kinetics',
#   'chemical',
#   'kinetics',
#   'chemical',
#   'kinetics',
#   'chemical',
#   'equilibria',
#   'chemical',
#   'equilibria',
#   'chemical',
#   'kinetics',
#   'chemical',
#   'equilibria',
#   'chemical',
#   'equilibria',
#   'midterm',
#   'acid',
#   'equilibria1',
#   'acid',
#   'equilibria2',
#   'acid',
#   'equilibria3',
#   'acid',
#   'equilibria1',
#   'acid',
#   'equilibria2',
#   'acid',
#   'equilibria3',
#   'chemical',
#   'thermodynamics',
#   'electrochemistry',
#   'chemical',
#   'thermodynamics',
#   'electrochemistry',
#   'midterm',
#   'nuclear',
#   'chemistry',
#   'coordination',
#   'chemistry',
#   'nuclear',
#   'chemistry',
#   'coordination',
#   'chemistry',
#   'return',
#   'chem'],
#  ['chem',
#   'environmental',
#   'chemistry',
#   'laboratory-',
#   'information',
#   'laboratory',
#   'meets',
#   '8:30am',
#   '12:20pm',
#   'experiments',
#   'scheduled',
#   'session',
#   'following',
#   'experiment',
#   'talk',
#   'experiment',
#   'significance',
#   'experiment',
#   'environmental',
#   'context',
#   'exchange',
#   'ideas',
#   'associated',
#   'ongoing',
#   'blackboard',
#   'discussions',
#   'intended',
#   'interactive',
#   'taking',
#   'lead',
#   'minor',
#   'guidance',
#   'experiments',
#   'groups',
#   'depending',
#   'size',
#   'written',
#   'following',
#   'completion',
#   'format',
#   'outlined',
#   'following',
#   'timeline',
#   'introductory',
#   'scheduled',
#   'procedure',
#   'check',
#   'lockers',
#   'obtain',
#   'safety',
#   'instructions',
#   'experiment',
#   'buffer',
#   'conductivity',
#   'natural',
#   'waters',
#   'chloride',
#   'natural',
#   'waters',
#   'iron',
#   'natural',
#   'waters',
#   'environmental',
#   'samples',
#   'photolysis',
#   'iron',
#   'chromatography',
#   'environmental',
#   'samples',
#   'phytoremediation',
#   'experimental',
#   'laboratory',
#   'format',
#   'numbers',
#   'proofread',
#   'submission',
#   'recommended',
#   'print',
#   'reports',
#   'double',
#   'sided',
#   'save',
#   'consist',
#   'title',
#   'contain',
#   'title',
#   'name(s',
#   'members',
#   'experiment',
#   'brief',
#   'background',
#   'experiment',
#   'example',
#   'reasons',
#   'experiment',
#   'performed',
#   'species',
#   'property',
#   'measured',
#   'instrument',
#   'measure',
#   'experimental',
#   'reagents',
#   'glassware',
#   'apparatus',
#   'manufacturer',
#   'model',
#   'instrumental',
#   'settings',
#   'sample',
#   'preparation',
#   'procedure',
#   'standardization',
#   'procedure',
#   'formulated',
#   'somebody',
#   'perform',
#   'results',
#   'data',
#   'organized',
#   'tables',
#   'properly',
#   'labeled',
#   'clearly',
#   'readable',
#   'understandable',
#   'sample',
#   'calculations',
#   'example',
#   'calculation',
#   'calculation',
#   'procedure',
#   'shown',
#   'including',
#   'proper',
#   'units',
#   'significant',
#   'figures',
#   'explained',
#   'sample',
#   'calculation',
#   'needs',
#   'labeled',
#   'trial',
#   'example',
#   'calculation',
#   'calculations',
#   'typed',
#   'handwritten',
#   'data',
#   'calculated',
#   'organized',
#   'tables',
#   'properly',
#   'labeled',
#   'graphs',
#   'figures',
#   'graphs',
#   'stand',
#   'numbered',
#   'labeled',
#   'properly',
#   'titled',
#   'brief',
#   'graph',
#   'figure',
#   'linear',
#   'regression',
#   'obtain',
#   'straight',
#   'lines',
#   'parameter',
#   'included',
#   'spectra',
#   'chromatograms',
#   'labeled',
#   'numbered',
#   'properly',
#   'handwritten',
#   'graphs',
#   'accepted',
#   'excel',
#   'graphing',
#   'program',
#   'generate',
#   'calibration',
#   'curves',
#   'refer',
#   'range',
#   'data',
#   'data',
#   'useful',
#   'sense',
#   'implications',
#   'data',
#   'kind',
#   'errors',
#   'meaning',
#   'data',
#   'respect',
#   'sample',
#   'analyzed',
#   'conclusions',
#   'conclude',
#   'experiment',
#   'respect',
#   'importance',
#   'method',
#   'selectivity',
#   'instrumentation',
#   'maybe',
#   'method',
#   'references',
#   'references',
#   'cited',
#   'accordance',
#   'published',
#   'journal',
#   'analytical',
#   'chemistry',
#   'style',
#   'like',
#   'peer',
#   'reviewed',
#   'pertinent',
#   'information',
#   'sections',
#   'clearly',
#   'labeled',
#   'despite',
#   'data',
#   'sharing',
#   'working',
#   'experiments',
#   'turn',
#   'calculations',
#   'conclusion',
#   'grading',
#   'scale',
#   'reports',
#   'worthy',
#   'points',
#   'distributed',
#   'following',
#   'title',
#   'experimental',
#   'results',
#   'conclusions',
#   'overall',
#   'appearance',
#   'points',
#   'points',
#   'points',
#   'points',
#   'points',
#   'points',
#   'points',
#   'points',
#   'taken',
#   'parts',
#   'missing',
#   'listed',
#   'items',
#   'detailed',
#   'experiments',
#   'determination',
#   'buffer',
#   'capacity',
#   'conductivity',
#   'natural',
#   'waters',
#   'chemicals',
#   'equipment',
#   'electrode',
#   'potentiometer',
#   'buffer',
#   'solutions',
#   'beakers',
#   'store',
#   'solutions',
#   'buret',
#   'ring',
#   'stand',
#   'buret',
#   'clamp',
#   'stirrer',
#   'determination',
#   'chloride',
#   'ions',
#   'natural',
#   'waters',
#   'chemicals',
#   'equipment',
#   'agno3',
#   '250ml',
#   'volumetric',
#   'flask',
#   '50ml',
#   'volumetric',
#   'pipets',
#   '250ml',
#   'erlenmeyer',
#   'meter',
#   'k2cro4',
#   'buret',
#   'hno3',
#   'naoh',
#   'caco3',
#   'conductivity',
#   'electrodes',
#   'stirrer',
#   'selective',
#   'electrode',
#   'chloride',
#   'electrode',
#   'waste',
#   'container',
#   'determination',
#   'iron',
#   'natural',
#   'waters',
#   'chemicals',
#   'equipment',
#   'spectrophotometer',
#   'cuvettes',
#   'kscn',
#   'conc',
#   'h2so4',
#   '6h2o',
#   'ferrous',
#   'ammonium',
#   'sulfate',
#   'hexahydrate',
#   'citrate',
#   'buffer',
#   'ph=4.5',
#   'hydroxylamine',
#   'hydrochloride',
#   'phenanthroline',
#   'meter',
#   '500ml',
#   '100ml(4x',
#   'volumetric',
#   'flask',
#   'balance',
#   'pipets',
#   '1.0ml',
#   'beakers',
#   'store',
#   'solutions',
#   'determination',
#   'environmental',
#   'samples',
#   'chemicals',
#   'equipment',
#   'sample',
#   'pipetts',
#   'plus',
#   'pipet',
#   'tips',
#   'standard',
#   'sample',
#   'preparation',
#   '200μl',
#   '1000μl',
#   'anthracene',
#   'naphthalene',
#   'solid',
#   'cyclohexane',
#   'analytical',
#   'balance',
#   'weigh',
#   'boats',
#   'scupula',
#   'water',
#   'quartz',
#   'glass',
#   'cuvettes',
#   '10ml',
#   'volumetric',
#   'flasks',
#   'notebook',
#   'calculator',
#   'spectrophotometer',
#   'photolysis',
#   'fe(iii',
#   'edta',
#   'chemicals',
#   'equipment',
#   'fecl3',
#   '6h2o',
#   'na2edta',
#   'naoh',
#   '10ml',
#   'volumetric',
#   'flasks',
#   'analytical',
#   'balance',
#   'weigh',
#   'boats',
#   'long',
#   'tube',
#   'aluminum',
#   'foil',
#   'sunlight',
#   'overhead',
#   'projector',
#   'analysis',
#   'inorganic',
#   'ions',
#   'environmental',
#   'samples',
#   'chromatography',
#   'chemicals',
#   'equipment',
#   'sample',
#   'eluent',
#   'naco3',
#   'nahco3',
#   'sulfuric',
#   'acid',
#   '18mohm',
#   'water',
#   'chromatograph',
#   'phytoremediation',
#   'copper',
#   'mustard',
#   'plants',
#   'chemicals',
#   'equipment',
#   'plant',
#   'pots',
#   'topsoil',
#   'mustard',
#   'seeds',
#   'water',
#   'edta',
#   'cuno3',
#   'znno3'],
#  ['chem203',
#   'captures',
#   'close',
#   'latest',
#   'news',
#   'cmck',
#   'charles',
#   'mckenna',
#   'barrios',
#   'chemistry',
#   'midnight',
#   'hints',
#   'combined',
#   'cmck',
#   'sure',
#   'khalsa',
#   'important',
#   'ebetino',
#   'bolger',
#   'calculations',
#   'kinds',
#   'calculator',
#   'strongly',
#   'recommended',
#   'sure',
#   'thermodynamics',
#   'enthalpy',
#   'entropy',
#   'corrected',
#   'slides',
#   'posted',
#   'enzyme',
#   'kinetics',
#   'including',
#   'plots',
#   'parameters',
#   'sure',
#   'chemistry',
#   'lectures',
#   'little',
#   'emphasis',
#   'drug',
#   'structures',
#   'recognize',
#   'acidity',
#   'basicity',
#   'concepts',
#   'like',
#   'related',
#   'briefly',
#   'diseases',
#   'mentioned',
#   'aids',
#   'good',
#   'luck',
#   'everybody',
#   'check',
#   'forum',
#   'tomorrow',
#   'view',
#   'shirt',
#   'design',
#   'artist',
#   'lange',
#   'chem',
#   'hours',
#   'barrios',
#   'maintain',
#   'scheduled',
#   'hours',
#   'addition',
#   'year',
#   'simultaneously',
#   'internet',
#   'hours',
#   'follows',
#   '10:00',
#   '10:50',
#   'session',
#   'webconference',
#   'live',
#   'audio',
#   'video',
#   'chemistry',
#   'password',
#   'pa55w0rd',
#   '10:00',
#   '10:50',
#   'pixion',
#   'webconference',
#   'picture',
#   'talk',
#   'instant',
#   'messaging',
#   'website',
#   'webconf.usc.edu',
#   'click',
#   '\x93attend\x94',
#   'fxta13',
#   'password',
#   'attendl',
#   'letter',
#   'lower',
#   'case',
#   'software',
#   'clients',
#   'free',
#   'download',
#   'website',
#   'session.usc.edu',
#   'information',
#   'experimental',
#   'internet',
#   'methods',
#   'instead',
#   'touch',
#   'wave3software',
#   'brice',
#   'kennedy',
#   'bookstore',
#   '3:30',
#   'address',
#   'software',
#   'client',
#   'scheduled',
#   'brice',
#   'shown',
#   'session',
#   'brice',
#   'downloaded',
#   'session',
#   'client',
#   'enter',
#   'address',
#   'password',
#   'needed',
#   'camera',
#   'microphone',
#   'function',
#   '\x96cmck',
#   'hope',
#   'everybody',
#   'good',
#   'thanksgiving',
#   'heading',
#   'lectures',
#   'formal',
#   'couldn',
#   'khalsa',
#   'guest',
#   'hint',
#   'sure',
#   'questions',
#   'grading',
#   'opportunity',
#   'evaluate',
#   'shirt',
#   'send',
#   'chem',
#   '203lg',
#   'shirt',
#   'design',
#   'tiff',
#   'photoship',
#   'format',
#   'barrios',
#   'taught',
#   'hint',
#   'sure',
#   'sign',
#   'achieve',
#   'immortality',
#   'annals',
#   'chem',
#   'year',
#   'winner',
#   'runner',
#   'guests',
#   'chem',
#   'christmas',
#   'party',
#   'truly',
#   'amazing',
#   'event',
#   'design(s',
#   'published',
#   'website',
#   'shirts',
#   'instead',
#   'cigars',
#   'chocolates',
#   'given',
#   'shirt',
#   'good',
#   'reason',
#   'shirt',
#   'case',
#   'gallery',
#   'past',
#   'created',
#   'shirt',
#   'designs',
#   'scroll',
#   'links',
#   'designs',
#   'finals',
#   'tends',
#   'hectic',
#   'period',
#   'everybody',
#   'professors',
#   'organize',
#   'grading',
#   'posting',
#   'schedules',
#   'order',
#   'plan',
#   'ahead',
#   'following',
#   'important',
#   'information',
#   'deadlines',
#   'schedules',
#   'session',
#   'actual',
#   'labwork',
#   'target',
#   'scores',
#   'plus',
#   'scores',
#   'posted',
#   'scores',
#   'scores',
#   'grades',
#   'missing',
#   'scores',
#   'everybody',
#   'offered',
#   'different',
#   'small',
#   'rooms',
#   'scattered',
#   'consider',
#   'ridiculous',
#   'instead',
#   'room',
#   'proctors',
#   'plan',
#   'stay',
#   'room',
#   'minimum',
#   'arriving',
#   'target',
#   'grading',
#   'letter',
#   'grades',
#   'results',
#   'provided',
#   'coffee',
#   'shirt',
#   'posted',
#   'lieu',
#   'cigar',
#   'posted',
#   'pick',
#   'graded',
#   'finals',
#   'noon',
#   'check',
#   'graded',
#   'room',
#   'immediately',
#   'grading',
#   'totalling',
#   'errors',
#   'entire',
#   'staff',
#   'consider',
#   'grading',
#   'errors',
#   'grades',
#   'submitted',
#   'registrar',
#   'shortly',
#   'come',
#   'pick',
#   'shirt',
#   '\x96cmck',
#   'james',
#   'hogan',
#   'hors',
#   'combat',
#   'days',
#   'acute',
#   'appendicitis',
#   'came',
#   'hospital',
#   'weekend',
#   'action',
#   'video',
#   'delayed',
#   'days',
#   'remember',
#   'gave',
#   'everybody',
#   'extension',
#   'labs',
#   'play',
#   'news',
#   'lately',
#   'clinical',
#   'trials',
#   'toxicity',
#   'problems',
#   'important',
#   'drugs',
#   'example',
#   'putting',
#   'vioxx',
#   'google',
#   'exactly',
#   'kind',
#   'discussing',
#   'remember',
#   'khalsa',
#   'giving',
#   'important',
#   'guest',
#   'current',
#   'state',
#   'aids',
#   'directs',
#   'aids',
#   'clinic',
#   'friends',
#   'interested',
#   'welcome',
#   'audit',
#   'opportunity',
#   'reasonable',
#   'earn',
#   'extra',
#   'points',
#   '\x96cmck',
#   'posting',
#   'hints',
#   'early',
#   'hopefully',
#   'guys',
#   'little',
#   'extra',
#   'sleep',
#   'tonite',
#   'bring',
#   'calculator',
#   'possible',
#   'solve',
#   'questions',
#   'calculator',
#   'easier',
#   'alternative',
#   'bonus',
#   'questions',
#   'worth',
#   'deal',
#   'subject',
#   'probability',
#   'statistics',
#   'chemical',
#   'structures',
#   'necessarily',
#   'separate',
#   'questions',
#   'questions',
#   'derived',
#   'bolger',
#   'slides',
#   'questions',
#   'derived',
#   'ebetino',
#   'short',
#   'concentrate',
#   'slides',
#   'oral',
#   'presentations',
#   'assigned',
#   'important',
#   'terms',
#   'reviewing',
#   'exams',
#   'helpful',
#   'entirely',
#   'questions',
#   'good',
#   'luck',
#   '\x96cmck',
#   'reminder',
#   'coming',
#   'rooms',
#   'tomorrow',
#   'guest',
#   'lecturer',
#   'ebetino',
#   'live',
#   'collected',
#   'bonus',
#   'points',
#   'asking',
#   'chance',
#   'submitted',
#   'questions',
#   'including',
#   'overtime',
#   'questions',
#   'bolger',
#   'points',
#   'posted',
#   'coming',
#   'overtime',
#   'questions',
#   'published',
#   'format',
#   'bolger',
#   'video',
#   'posted',
#   'slides',
#   'usual',
#   'interactive',
#   'format',
#   'ebetino',
#   'video',
#   'slides',
#   'posted',
#   'cover',
#   'bolger',
#   'ebetino',
#   'lectures',
#   'announced',
#   'reception',
#   'honoring',
#   'ebetino',
#   'held',
#   'guest',
#   'residence',
#   'bunker',
#   'hill',
#   'downtown',
#   'today',
#   '7:30',
#   'chance',
#   'c203',
#   'activities',
#   'working',
#   'drug',
#   'discovery',
#   'drug',
#   'company',
#   'plus',
#   'staff',
#   'informal',
#   'setting',
#   'like',
#   'attend',
#   'sign',
#   'yesterday',
#   '5:30',
#   'today',
#   'posting',
#   'midnite',
#   'hints',
#   'news',
#   '\x96cmck',
#   'midnight',
#   'hints',
#   'little',
#   'early',
#   'challenging',
#   'sure',
#   'know',
#   'notes',
#   'backwards',
#   'forwards',
#   'sure',
#   'download',
#   'corrected',
#   'notes',
#   'calculator',
#   'needed',
#   'sure',
#   'comfortable',
#   'forget',
#   'lectures',
#   'electron',
#   'counting',
#   'valence',
#   'bonus',
#   'news',
#   'conducting',
#   'formal',
#   'education',
#   'program',
#   'opinion',
#   'important',
#   'plan',
#   'attending',
#   'comments',
#   'improve',
#   'year',
#   'incorporate',
#   'thoughts',
#   'rest',
#   '\x96amb',
#   'invited',
#   'attend',
#   'explosive',
#   'surprise',
#   'demonstration',
#   '^_^.',
#   'sorry',
#   'thrown',
#   'forum',
#   'original',
#   'highly',
#   'original',
#   'wording',
#   'notice',
#   'posted',
#   'fluent',
#   'native',
#   'english',
#   'speaker',
#   'hope',
#   'enjoyed',
#   'demo',
#   '\x96cmck',
#   'probably',
#   'noticed',
#   'movies',
#   'posted',
#   'faster',
#   'requested',
#   'improve',
#   'production',
#   'target',
#   'hours',
#   'hours',
#   'movies',
#   'posted',
#   'combination',
#   'good',
#   'cinema',
#   'chris',
#   'rozé',
#   'acquisition',
#   '2x2ghz',
#   'power',
#   'macintosh',
#   'dedicated',
#   'movie',
#   'production',
#   'movie',
#   'rendering',
#   'hours',
#   'machine',
#   'herreros',
#   'bruno',
#   'instrumental',
#   'helping',
#   'technical',
#   'obstacles',
#   '\x96cmck',
#   'barrios',
#   'commented',
#   'today',
#   'disastrous',
#   'merck',
#   'stock',
#   'announcement',
#   'clinical',
#   'trial',
#   'failure',
#   'therapeutic',
#   'effect',
#   'resulting',
#   'effect',
#   'emerged',
#   'talk',
#   'clinical',
#   'trials',
#   'constitutes',
#   'success',
#   'failure',
#   'business',
#   'ethical',
#   'issues',
#   'arise',
#   '\x96cmck',
#   'movies',
#   'tomorrow',
#   'morning',
#   'nite',
#   'tested',
#   'viewing',
#   'bucks',
#   'wilshire',
#   'barrington',
#   'outside',
#   'view',
#   'inside',
#   'tmobile',
#   'coffee',
#   'shops',
#   'airport',
#   'bars',
#   'signal',
#   'strength',
#   'users',
#   'load',
#   'delay',
#   'minutes',
#   'watch',
#   'hear',
#   'including',
#   'prof',
#   'barrios',
#   'video',
#   'interactive',
#   'slides',
#   'good',
#   'quality',
#   'like',
#   'input',
#   'movie',
#   'viewing',
#   'different',
#   'sites',
#   'different',
#   'platforms',
#   'different',
#   'connect',
#   'speeds',
#   'send',
#   'reports',
#   'directly',
#   'bruno',
#   'photos',
#   'incidentally',
#   'location',
#   'crammed',
#   'ucla',
#   'studying',
#   'fashioned',
#   'textbooks',
#   'hand',
#   'written',
#   'notes',
#   'amazed',
#   'bruins',
#   'came',
#   'look',
#   'wistfully',
#   'trojan',
#   'technology',
#   'action',
#   '\x96cmck',
#   'reminder',
#   'posting',
#   'movies',
#   'lectures',
#   'links',
#   'found',
#   'format',
#   'format',
#   'soon',
#   'updated',
#   'format',
#   'currently',
#   'processing',
#   'forum',
#   'comments',
#   'view',
#   'movies',
#   'feedback',
#   'appreciated',
#   '\x96cmck',
#   'prof',
#   'barrios',
#   'know',
#   'photos',
#   'trip',
#   'italy',
#   'sent',
#   'bruno',
#   'trip',
#   'paris',
#   'month',
#   'shot',
#   'vavin',
#   'montparnasse',
#   'cafe',
#   'provided',
#   'free',
#   'wireless',
#   'ordered',
#   'coffee',
#   'shows',
#   'working',
#   'slides',
#   'apparently',
#   'view',
#   'pictures',
#   '\x96cmck',
#   'shortly',
#   'lectures',
#   'cmck',
#   'modified',
#   'sllides',
#   'posted',
#   'tonight',
#   'midnight',
#   'trying',
#   'register',
#   'official',
#   'instead',
#   'block',
#   'cmck',
#   'looks',
#   'like',
#   'good',
#   'welcome',
#   'chem',
#   '203lg',
#   'year',
#   'team',
#   'taught',
#   'professors',
#   'charles',
#   'mckenna',
#   'barrios',
#   'notes',
#   'slides',
#   'currently',
#   'updated',
#   'rest',
#   'website',
#   'notification',
#   'slides',
#   'letter',
#   'grades',
#   'results',
#   'pretty',
#   'good',
#   'distribution',
#   'shirt',
#   'pick',
#   'graded',
#   'hopefully',
#   'shirt',
#   'tomorrow',
#   'thanks',
#   'great',
#   'shirt',
#   'year',
#   'outstandingly',
#   'original',
#   'designs',
#   'offering',
#   'choice',
#   'supplies',
#   'clever',
#   'c203',
#   'banknote',
#   'design',
#   'gabe',
#   'barerras',
#   'notice',
#   'interesting',
#   'details',
#   'witty',
#   'movie',
#   'poster',
#   'parody',
#   'chris',
#   'rozé',
#   'shirt',
#   'shows',
#   'image',
#   'thanks',
#   'rachel',
#   'shpringer',
#   'contributing',
#   'design',
#   'influenced',
#   'versions',
#   'posted',
#   'shirt',
#   'tomorrow',
#   'nite',
#   'guaranteed',
#   'shirt',
#   'writes',
#   'requesting',
#   'shirt',
#   'come',
#   'come',
#   'serve',
#   'midnight',
#   'hints',
#   'statistics',
#   'probability',
#   'related',
#   'questions',
#   'know',
#   'drug',
#   'structures',
#   'plus',
#   'draw',
#   'barrios',
#   'calculator',
#   'allowed',
#   'helpful',
#   'bonus',
#   'related',
#   'good',
#   'luck',
#   'everybody',
#   'shirts',
#   'waiting',
#   'incredible',
#   'khalsa',
#   'speaks',
#   'sure',
#   'attend',
#   'khalsa',
#   'guest',
#   'aids',
#   'clinic',
#   'tomorrow',
#   'regular',
#   'guest',
#   'attendees',
#   'welcome',
#   'filming',
#   'posting',
#   'barring',
#   'glitches',
#   'khalsa',
#   'actual',
#   'slides',
#   'posting',
#   'shirts',
#   'chem',
#   'shirt',
#   'designs',
#   'designers',
#   'version',
#   'shirt',
#   'regardless',
#   'good',
#   'reason',
#   'want',
#   'shirt',
#   'ahead',
#   'usually',
#   'limited',
#   'number',
#   'extras',
#   'finals',
#   'tends',
#   'hectic',
#   'period',
#   'everybody',
#   'professors',
#   'organize',
#   'grading',
#   'posting',
#   'schedules',
#   'order',
#   'plan',
#   'ahead',
#   'following',
#   'important',
#   'information',
#   'deadlines',
#   'schedules',
#   'holiday',
#   'sections',
#   'gives',
#   'little',
#   'extra',
#   'enjoy',
#   'xgiving',
#   'session',
#   'target',
#   'scores',
#   'posted',
#   'scores',
#   'scores',
#   'grades',
#   'missing',
#   'scores',
#   'answer',
#   'questions',
#   'grading',
#   'check',
#   'website',
#   'room',
#   'locations',
#   'ahead',
#   'room',
#   'single',
#   'room',
#   'edison',
#   'auditorium',
#   'hoffman',
#   'hall',
#   'plan',
#   'stay',
#   'room',
#   'minimum',
#   'arriving',
#   'target',
#   'grading',
#   'letter',
#   'grades',
#   'results',
#   'provided',
#   'coffee',
#   'shirt',
#   'posted',
#   'lieu',
#   'cigar',
#   'pick',
#   'graded',
#   'finals',
#   'noon',
#   'check',
#   'graded',
#   'room',
#   'immediately',
#   'grading',
#   'totalling',
#   'errors',
#   'entire',
#   'staff',
#   'consider',
#   'grading',
#   'errors',
#   'grades',
#   'submitted',
#   'registrar',
#   'shortly',
#   'come',
#   'pick',
#   'shirt',
#   'midnight',
#   'hints',
#   'statistics',
#   'probability',
#   'related',
#   'questions',
#   'qsar',
#   'related',
#   'questions',
#   'questions',
#   'based',
#   'slides',
#   'derived',
#   'patrick',
#   'calculator',
#   'allowed',
#   'little',
#   'heavy',
#   'duty',
#   'calcs',
#   'bonus',
#   'related',
#   'good',
#   'luck',
#   'everybody',
#   'cigars',
#   'waiting',
#   'ebetino',
#   'slides',
#   'today',
#   'posted',
#   'files',
#   'summary',
#   'ebetino',
#   'movie',
#   'video',
#   'audio',
#   'slides',
#   'posted',
#   'place',
#   'real',
#   'player',
#   'view',
#   'movie',
#   'attempt',
#   ...],
#  ['chem',
#   'spring',
#   'information',
#   'details',
#   'hours',
#   'telephone',
#   'jeremy',
#   'maddox',
#   'tccw',
#   '1–3pm',
#   'appointment',
#   'details',
#   'title',
#   'location',
#   'corequisite',
#   'summary',
#   'chem',
#   'chemistry',
#   '9:10',
#   '10:05',
#   'chem',
#   'better',
#   'math',
#   'chem',
#   'continuation',
#   'year',
#   'chemistry',
#   'science',
#   'majors',
#   'minors',
#   'satisfactory',
#   'education',
#   'requirements',
#   'science',
#   'majors',
#   'minors',
#   'required',
#   'title',
#   'author(s',
#   'publisher',
#   'isbn',
#   'note(s',
#   'chemistry',
#   'ebbing',
#   'gammon',
#   'houghton',
#   'mifflin',
#   'york',
#   'software',
#   'needed',
#   'learning',
#   'objectives',
#   'demonstrate',
#   'proficiency',
#   'chemical',
#   'knowledge',
#   'solving',
#   'skills',
#   'following',
#   'topics',
#   'solution',
#   'properties',
#   'chemical',
#   'kinetics',
#   'equilibrium',
#   'acid',
#   'chemistry',
#   'equilibria',
#   'solubility',
#   'thermodynamics',
#   'electrochemistry',
#   'nuclear',
#   'chemistry',
#   'assignments',
#   'sets',
#   'assigned',
#   'regularly',
#   'significant',
#   'commitment',
#   'outside',
#   'detailed',
#   'cover',
#   'topics',
#   'required',
#   'sets',
#   'collected',
#   'imperative',
#   'problems',
#   'timely',
#   'fashion',
#   'encouraged',
#   'hours',
#   'assistance',
#   'problems',
#   'needed',
#   'chem',
#   'spring',
#   'examinations',
#   'multiple',
#   'exams',
#   'comprehensive',
#   'reserves',
#   'modify',
#   'order',
#   'constraints',
#   'given',
#   'advanced',
#   'notice',
#   'dates',
#   'exams',
#   'closed',
#   'closed',
#   'notes',
#   'standardized',
#   'produced',
#   'american',
#   'chemical',
#   'society',
#   'covers',
#   'topics',
#   'chem',
#   'chem',
#   'administered',
#   'afternoon',
#   'finals',
#   'grading',
#   'policy',
#   'numeric',
#   'scores',
#   'exams',
#   'scores',
#   'carry',
#   'equal',
#   'weight',
#   'determining',
#   'average',
#   'score',
#   'normalized',
#   'average',
#   'score',
#   'letter',
#   'grades',
#   'based',
#   'following',
#   'scale',
#   'responsible',
#   'initiating',
#   'changes',
#   'enrollment',
#   'status',
#   'registrar',
#   'services',
#   'compliance',
#   'policy',
#   'disabilities',
#   'auxiliary',
#   'accommodations',
#   'services',
#   'downing',
#   'a-200',
#   'number',
#   'request',
#   'accommodations',
#   'directly',
#   'letter',
#   'services',
#   'policy',
#   'policy',
#   'handbook',
#   'followed',
#   'registration',
#   'obligates',
#   'regular',
#   'punctual',
#   'absent',
#   'illness',
#   'death',
#   'family',
#   'justifiable',
#   'reasons',
#   'responsibility',
#   'soon',
#   'possible',
#   'misses',
#   'legitimate',
#   'reason',
#   'consider',
#   'request',
#   'chance',
#   'period',
#   'different',
#   'allowance',
#   'request',
#   'subject',
#   'discretion',
#   'hours',
#   'acceptable',
#   'documentation',
#   'specifically',
#   'excuses',
#   'scheduled',
#   'period',
#   'dates',
#   'exams',
#   'disruptions',
#   'digital',
#   'devices',
#   'coursework',
#   'related',
#   'conversations',
#   'create',
#   'significant',
#   'disruption',
#   'disruptive',
#   'behavior',
#   'makes',
#   'difficult',
#   'concentrate',
#   'chem',
#   'spring',
#   'learning',
#   'objectives',
#   'tolerated',
#   'create',
#   'disruption',
#   'dismissed',
#   'sanctions',
#   'brought',
#   'persistently',
#   'disrupt',
#   'cheating',
#   'policy',
#   'handbook',
#   'followed',
#   'commit',
#   'failing',
#   'portion',
#   'coursework',
#   'detected',
#   'failing',
#   'possibility',
#   'withdrawal',
#   'member',
#   'case',
#   'judicial',
#   'affairs',
#   'affairs',
#   'disciplinary',
#   'sanctions'],
#  ['chemistry',
#   'physical',
#   'chemistry',
#   'spring',
#   'glenn',
#   'beauregard',
#   'hours',
#   '9:35',
#   '10:35',
#   'appointment',
#   'chem',
#   'physical',
#   'chemistry',
#   'continuation',
#   'chem',
#   'physical',
#   'chemistry',
#   'prerequisites',
#   'math',
#   'chem',
#   'phys',
#   'states',
#   'matter',
#   'elementary',
#   'thermodynamics',
#   'thermochemistry',
#   'solutions',
#   'homogeneous',
#   'heterogeneous',
#   'equilibria',
#   'reaction',
#   'kinetics',
#   'atomic',
#   'molecular',
#   'structure',
#   'prerequisites',
#   'chem',
#   'peter',
#   'atkins',
#   'julio',
#   'paula',
#   'physical',
#   'chemistry',
#   'freeman',
#   'york',
#   'supplements',
#   'handouts',
#   'pertinent',
#   'references',
#   'provided',
#   'website',
#   'moodle2.nicholls.edu/moodle',
#   'goal',
#   'acquire',
#   'firm',
#   'mathematically',
#   'rigorous',
#   'understanding',
#   'principles',
#   'thermodynamics',
#   'applied',
#   'chemical',
#   'systems',
#   'objectives',
#   'state',
#   'laws',
#   'thermodynamics',
#   'phenomenological',
#   'basis',
#   'molecular',
#   'interpretation',
#   'principles',
#   'thermodynamics',
#   'problems',
#   'dealing',
#   'equilibrium',
#   'physico',
#   'chemical',
#   'systems',
#   'content',
#   'properties',
#   'gases',
#   'physical',
#   'transformation',
#   'pure',
#   'susbtances',
#   'simple',
#   'mixtures',
#   'phase',
#   'diagrams',
#   'chemical',
#   'equilibrium',
#   'requirements',
#   'exams',
#   '3x100',
#   'points',
#   'points',
#   'consist',
#   'selected',
#   'questions',
#   'standardized',
#   'tests',
#   'thermodynamics',
#   'american',
#   'chemical',
#   'society',
#   'examinations',
#   'institute',
#   'optional',
#   'assigned',
#   'adjustments',
#   'score',
#   'methods',
#   'grades',
#   'assigned',
#   'according',
#   'average',
#   'follows',
#   'policy',
#   'decided',
#   'case',
#   'case',
#   'basis',
#   'valid',
#   'verifiable',
#   'excuse',
#   'missed',
#   'exams',
#   'honesty',
#   'code',
#   'disruptive',
#   'behavior',
#   'includes',
#   'file',
#   'charge',
#   'complaint',
#   'statement',
#   'respective',
#   'dean',
#   'confronted',
#   'disciplined',
#   'cheating',
#   'affairs',
#   'maintain',
#   'records',
#   'confronted',
#   'disciplined',
#   'multiple',
#   'offenses',
#   'brought',
#   'affairs',
#   'committee',
#   'potential',
#   'sanctions',
#   'code',
#   'details',
#   'policy',
#   'withdrawals',
#   'grievances',
#   'proper',
#   'procedure',
#   'filing',
#   'appeals',
#   'grievances',
#   'related',
#   'matters',
#   'listed',
#   'code',
#   'following',
#   'link',
#   'http://www.nicholls.edu/documents/student_life/code_of_conduct.pdf',
#   'blank',
#   'http://www.nicholls.edu/documents/student_life/code_of_conduct.pdf',
#   'continued',
#   'learning',
#   'following',
#   'extreme',
#   'emergency',
#   'order',
#   'continued',
#   'learning',
#   'possible',
#   'following',
#   'extreme',
#   'emergency',
#   'responsible',
#   'regular',
#   'emergency',
#   'notifications',
#   'website',
#   'knowing',
#   'blackboard',
#   'designated',
#   'electronic',
#   'delivery',
#   'familiar',
#   'emergency',
#   'guidelines',
#   'evacuating',
#   'textbooks',
#   'materials',
#   'knowing',
#   'blackboard',
#   'designated',
#   'login',
#   'password',
#   'contacting',
#   'intentions',
#   'completing',
#   'responsible',
#   'development',
#   'blackboard',
#   'designated',
#   'software',
#   'having',
#   'plan',
#   'continuing',
#   'courses',
#   'blackboard',
#   'continuing',
#   'suits',
#   'completion',
#   'best',
#   'creative',
#   'continuation',
#   'courses',
#   'making',
#   'adjustments',
#   'compensations',
#   'progress',
#   'special',
#   'programs',
#   'labs',
#   'clinical',
#   'sequences',
#   'like',
#   'immediate',
#   'following',
#   'emergency',
#   'disabilities',
#   'documented',
#   'requires',
#   'assistance',
#   'register',
#   'services',
#   'coordination',
#   'accommodations',
#   'services',
#   'located',
#   'peltier',
#   'hall',
#   'room',
#   'number',
#   'disclaimer',
#   'contract',
#   'construed',
#   'subject',
#   'change',
#   'notified',
#   'changes',
#   'timely',
#   'manner'],
#  ['advice',
#   'philosophical',
#   'approach',
#   'organic',
#   'chemistry',
#   'requires',
#   'different',
#   'thought',
#   'process',
#   'classes',
#   'classes',
#   'sole',
#   'process',
#   'fact',
#   'regurgitation',
#   'example',
#   'history',
#   'tell',
#   'christopher',
#   'columbus',
#   'sent',
#   'sail',
#   'long',
#   'know',
#   'fact',
#   'fine',
#   'sail',
#   'columbus',
#   'columbus',
#   'sail',
#   'hards',
#   'teachers',
#   'actually',
#   'describe',
#   'significant',
#   'events',
#   'thier',
#   'impact',
#   'regardless',
#   'long',
#   'know',
#   'initial',
#   'fact',
#   'fine',
#   'organic',
#   'required',
#   'know',
#   'facts',
#   'certain',
#   'situations',
#   'usually',
#   'important',
#   'know',
#   'happens',
#   'know',
#   'happens',
#   'example',
#   'tell',
#   'equal',
#   'happens',
#   'equals',
#   'exact',
#   'process',
#   'seen',
#   'example',
#   'answer',
#   'reason',
#   'important',
#   'focus',
#   'generic',
#   'examples',
#   'double',
#   'bonds',
#   'reacts',
#   'hydrogen',
#   'metal',
#   'catalyst',
#   'single',
#   'bond',
#   'double',
#   'bonds',
#   'react',
#   'regardless',
#   'carbons',
#   'compound',
#   'memorize',
#   'difference',
#   'memorizing',
#   'learning',
#   'practically',
#   'impossible',
#   'memorize',
#   'information',
#   'presented',
#   'took',
#   'organic',
#   'undergrad',
#   'classmate',
#   'tried',
#   'card',
#   'reaction',
#   'teacher',
#   'presented',
#   'definition',
#   'cards',
#   'knew',
#   'information',
#   'cards',
#   'failed',
#   'failed',
#   'know',
#   'things',
#   'happened',
#   'different',
#   'compound',
#   'example',
#   'react',
#   'lost',
#   'reason',
#   'medical',
#   'schools',
#   'professional',
#   'schools',
#   'look',
#   'heavily',
#   'organic',
#   'classes',
#   'covers',
#   'vast',
#   'information',
#   'comparable',
#   'covered',
#   'medical',
#   'requires',
#   'know',
#   'know',
#   'want',
#   'doctor',
#   'knows',
#   'aspirian',
#   'fever',
#   'want',
#   'doctor',
#   'figure',
#   'fever',
#   'treat',
#   'organization',
#   'important',
#   'start',
#   'covering',
#   'reactions',
#   'reactions',
#   'straight',
#   'suggest',
#   'create',
#   'separate',
#   'pages',
#   'compound',
#   'structure',
#   'bond',
#   'angle',
#   'hybridization',
#   'naming',
#   'synthesis',
#   'compounds',
#   'reaction',
#   'gives',
#   'type',
#   'compound',
#   'product',
#   'reaction',
#   'reactions',
#   'compound',
#   'everytime',
#   'reaction',
#   'type',
#   'compound',
#   'reactant',
#   'pages',
#   'night',
#   'problems',
#   'problems',
#   'problems',
#   'problems',
#   'organic',
#   'chemistry',
#   'different',
#   'organic',
#   'books',
#   'welcome',
#   'borrow',
#   'problems',
#   'books',
#   'different',
#   'books',
#   'little',
#   'different',
#   'explain',
#   'little',
#   'different',
#   'problems',
#   'possible',
#   'adage',
#   'classes',
#   'hours',
#   'organic',
#   'triple',
#   'proven',
#   'fact',
#   'exposed',
#   'advantage',
#   'ahead',
#   'night',
#   'exposure',
#   'probably',
#   'exposed',
#   'exposure',
#   'better',
#   'prepared',
#   'questions',
#   'notes',
#   'night',
#   'exposure',
#   '4,etc',
#   'organic',
#   'hesitate',
#   'tell',
#   'studied',
#   'hours',
#   'outside',
#   'groups',
#   'groups',
#   'definately',
#   'know',
#   'like',
#   'strongly',
#   'strongly',
#   'encourage',
#   'participate',
#   'groups',
#   'reasons',
#   'points',
#   'participating',
#   'points',
#   'odds',
#   'explain',
#   'know',
#   'best',
#   'actually',
#   'know',
#   'explain',
#   'groups',
#   'people',
#   'effective',
#   'selected',
#   'times',
#   'needs',
#   'night',
#   'groups',
#   'half',
#   'times',
#   'hole',
#   'organic',
#   'builds',
#   'fast',
#   'immediately',
#   'wait',
#   'going',
#   'weekend',
#   'probably',
#   'till',
#   'like'],
#  ['                       ',
#   'chem',
#   'bioinorganic',
#   'chemistry',
#   'spring',
#   'brad',
#   'pierce',
#   'number',
#   'science',
#   'hall',
#   '300f',
#   'telephone',
#   'number',
#   'address',
#   'hours',
#   '11am',
#   'place',
#   'meetings',
#   'content',
#   'fundamental',
#   'life',
#   'processes',
#   'respiration',
#   'nitrogen',
#   'fixation',
#   'photosynthesis',
#   'replication',
#   'transition',
#   'metal',
#   'ions',
#   'elements',
#   'outside',
#   'traditional',
#   'preview',
#   'organic',
#   'chemistry',
#   'focus',
#   'basis',
#   'understanding',
#   'transition',
#   'metal',
#   'ions',
#   'utilized',
#   'biological',
#   'catalysts',
#   'enzymes',
#   'atom',
#   'transfer',
#   'electron',
#   'transport',
#   'additionally',
#   'variety',
#   'commonly',
#   'employed',
#   'physical',
#   'methods',
#   'optical',
#   'magnetic',
#   'introduced',
#   'application',
#   'determination',
#   'electronic',
#   'molecular',
#   'structure',
#   'enzymatic',
#   'mechanisms',
#   'learning',
#   'outcomes',
#   'successful',
#   'completion',
#   'familiar',
#   'variety',
#   'common',
#   'metalloenzyme',
#   'cofactors',
#   'reactivity',
#   'biogeochemical',
#   'cycles',
#   'drive',
#   'metal',
#   'bioavailability',
#   'emphasis',
#   'placed',
#   'practical',
#   'interpretation',
#   'experimental',
#   'spectroscopic',
#   'computational',
#   'methods',
#   'frequently',
#   'employed',
#   'modern',
#   'bioinorganic',
#   'research',
#   'expected',
#   'theoretical',
#   'concepts',
#   'solve',
#   'real',
#   'world',
#   'problems',
#   'relevant',
#   'bioinorganic',
#   'chemistry',
#   'required',
#   'biological',
#   'inorganic',
#   'chemistry',
#   'structure',
#   'reactivity',
#   'ivano',
#   'bertini',
#   'harry',
#   'gray',
#   'edward',
#   'stiefel',
#   'joan',
#   'valentine',
#   'science',
#   'books',
#   'supplemental',
#   'texts',
#   'principles',
#   'bioinorganic',
#   'chemistry',
#   'lippard',
#   'berg',
#   'physical',
#   'methods',
#   'bioinorganic',
#   'chemistry',
#   'science',
#   'books',
#   'physical',
#   'methods',
#   'chemists',
#   'russell',
#   'drago',
#   'saunders',
#   'publishing',
#   'assigments',
#   'examinations',
#   'sets',
#   'sets',
#   'assigned',
#   'assess',
#   'knowledge',
#   'real',
#   'world',
#   'examples',
#   'relevant',
#   'inorganic',
#   'biochemistry',
#   'represent',
#   'literature',
#   'literature',
#   'approved',
#   'relevant',
#   'bioinorganic',
#   'chemistry',
#   'research',
#   'concerned',
#   'transition',
#   'metals',
#   'biological',
#   'systems',
#   'synthetic',
#   'model',
#   'complexes',
#   'spectroscopic',
#   'quantitative',
#   'analysis',
#   'longer',
#   'pages',
#   'including',
#   'references',
#   'written',
#   'standard',
#   'format',
#   'chem',
#   'communications',
#   'template',
#   'topics',
#   'literature',
#   'approved',
#   'reviews',
#   'represents',
#   'overall',
#   'provided',
#   'opportunities',
#   'current',
#   'literature',
#   'percent',
#   'based',
#   'discussions',
#   'presentations',
#   'important',
#   'responsible',
#   'assigned',
#   'presented',
#   'regardless',
#   'requirements',
#   'expectations',
#   'required',
#   'attend',
#   'enrolled',
#   'spend',
#   'hours',
#   'related',
#   'activities',
#   'including',
#   'required',
#   'materials',
#   'completing',
#   'assignments',
#   'preparing',
#   'exams',
#   'policy',
#   'swap',
#   'adding',
#   'dropping',
#   'concurrently',
#   'classes',
#   'self',
#   'mymav',
#   'beginning',
#   'registration',
#   'period',
#   'registration',
#   'period',
#   'registration',
#   'period',
#   'advisor',
#   'undeclared',
#   'advisor',
#   'advising',
#   'drops',
#   'continue',
#   'thirds',
#   'session',
#   'responsibility',
#   'officially',
#   'plan',
#   'attend',
#   'registering',
#   'automatically',
#   'dropped',
#   'repayment',
#   'certain',
#   'types',
#   'financial',
#   'administered',
#   'required',
#   'dropping',
#   'classes',
#   'withdrawing',
#   'information',
#   'financial',
#   'scholarships',
#   'http://wweb.uta.edu/ses/fao',
#   'americans',
#   'disabilities',
#   'texas',
#   'arlington',
#   'record',
#   'committed',
#   'spirit',
#   'letter',
#   'federal',
#   'equal',
#   'opportunity',
#   'legislation',
#   'including',
#   'americans',
#   'disabilities',
#   'instructors',
#   'arlington',
#   'required',
#   'reasonable',
#   'accommodations',
#   'disabilities',
#   'discriminate',
#   'basis',
#   'official',
#   'documentation',
#   'letter',
#   'certified',
#   'staff',
#   'disabilities',
#   'hall',
#   'officially',
#   'documented',
#   'request',
#   'honored',
#   'information',
#   'diagnostic',
#   'criteria',
#   'policies',
#   'obtaining',
#   'based',
#   'accommodations',
#   'found',
#   'www.uta.edu/disability',
#   'calling',
#   'disabilities',
#   'kind',
#   'tolerated',
#   'exception',
#   'offenses',
#   'immediate',
#   'failure',
#   'referral',
#   'arlington',
#   'board',
#   'affairs',
#   'disciplinary',
#   'action',
#   'enrolled',
#   'expected',
#   'adhere',
#   'arlington',
#   'honor',
#   'code',
#   'pledge',
#   'honor',
#   'uphold',
#   'arlington',
#   'tradition',
#   'tradition',
#   'values',
#   'hard',
#   'honest',
#   'effort',
#   'pursuit',
#   'excellence',
#   'promise',
#   'personally',
#   'create',
#   'contribute',
#   'collaborations',
#   'appropriately',
#   'reference',
#   'sources',
#   'highest',
#   'standards',
#   'uphold',
#   'spirit',
#   'honor',
#   'code',
#   'services',
#   'arlington',
#   'provides',
#   'variety',
#   'resources',
#   'programs',
#   'designed',
#   'develop',
#   'skills',
#   'deal',
#   'personal',
#   'situations',
#   'better',
#   'concepts',
#   'information',
#   'related',
#   'courses',
#   'resources',
#   'tutoring',
#   'based',
#   'learning',
#   'centers',
#   'developmental',
#   'education',
#   'advising',
#   'mentoring',
#   'personal',
#   'counseling',
#   'federally',
#   'funded',
#   'programs',
#   'individualized',
#   'referrals',
#   'visit',
#   'reception',
#   'desk',
#   'ransom',
#   'hall',
#   'maverick',
#   'hotline',
#   'send',
#   'message',
#   'view',
#   'information',
#   'www.uta.edu/resources',
#   'electronic',
#   'communication',
#   'arlington',
#   'adopted',
#   'mavmail',
#   'official',
#   'means',
#   'communicate',
#   'important',
#   'deadlines',
#   'events',
#   'transact',
#   'related',
#   'business',
#   'financial',
#   'tuition',
#   'grades',
#   'graduation',
#   'assigned',
#   'mavmail',
#   'account',
#   'responsible',
#   'checking',
#   'inbox',
#   'regularly',
#   'charge',
#   'account',
#   'remains',
#   'active',
#   'graduation',
#   'information',
#   'activating',
#   'mavmail',
#   'http://www.uta.edu/oit/cs/email/mavmail.php',
#   'feedback',
#   'survey',
#   'enrolled',
#   'classes',
#   'categorized',
#   'seminar',
#   'laboratory',
#   'shall',
#   'directed',
#   'feedback',
#   'survey',
#   'instructions',
#   'sent',
#   'directly',
#   'mavmail',
#   'approximately',
#   'days',
#   'feedback',
#   'enters',
#   'database',
#   'anonymously',
#   'aggregated',
#   'enrolled',
#   'arlington',
#   'effort',
#   'solicit',
#   'gather',
#   'tabulate',
#   'publish',
#   'feedback',
#   'required',
#   'state',
#   'strongly',
#   'urged',
#   'participate',
#   'information',
#   'visit',
#   'http://www.uta.edu/sfs',
#   'period',
#   'days',
#   'prior',
#   'examinations',
#   'long',
#   'sessions',
#   'shall',
#   'designated',
#   'purpose',
#   'allow',
#   'sufficient',
#   'examinations',
#   'shall',
#   'scheduled',
#   'activities',
#   'required',
#   'field',
#   'trips',
#   'performances',
#   'shall',
#   'themes',
#   'research',
#   'problems',
#   'exercises',
#   'similar',
#   'scope',
#   'completion',
#   'following',
#   'specified',
#   'shall',
#   'examinations',
#   'constituting',
#   'makeup',
#   'tests',
#   'laboratory',
#   'examinations',
#   'addition',
#   'shall',
#   'portion',
#   'classes',
#   'held',
#   'scheduled',
#   'addition',
#   'instructors',
#   'required',
#   'limit',
#   'content',
#   'topics',
#   'previously',
#   'covered',
#   'introduce',
#   'concepts'],
#  ['chem',
#   'hybrid',
#   '3:00',
#   '4:20pm',
#   'holden',
#   'hall',
#   'gellene',
#   'chemistry',
#   'leave',
#   'messages',
#   'required',
#   'mindtap',
#   'chemistry',
#   'edition',
#   'vining',
#   'young',
#   'botch',
#   'cengage',
#   'blackboard',
#   'direct',
#   'purchase',
#   'registration',
#   'turning',
#   'systems',
#   'clickers',
#   'chemistry',
#   'edition',
#   'vining',
#   'young',
#   'botch',
#   'cengage',
#   'notes',
#   'area',
#   'bookstores',
#   'blackboard',
#   'www.blackboard.ttu.edu',
#   'optional',
#   'outline',
#   'cover',
#   'chapters',
#   'chemistry',
#   'edition',
#   'vining',
#   'young',
#   'botch',
#   'cengage',
#   'learning',
#   'partially',
#   'satisfy',
#   'natural',
#   'science',
#   'core',
#   'curriculum',
#   'learning',
#   'outcomes',
#   'enabling',
#   'construct',
#   'evaluate',
#   'relationships',
#   'natural',
#   'sciences',
#   'bases',
#   'building',
#   'testing',
#   'theories',
#   'fully',
#   'successful',
#   'realize',
#   'following',
#   'specific',
#   'learning',
#   'outcomes',
#   'dimensional',
#   'analysis',
#   'proper',
#   'attention',
#   'units',
#   'significant',
#   'figures',
#   'classify',
#   'inorganic',
#   'compounds',
#   'determine',
#   'empirical',
#   'molecular',
#   'formulas',
#   'empirical',
#   'data',
#   'mole',
#   'concept',
#   'stoichiometry',
#   'reactions',
#   'solutions',
#   'balance',
#   'chemical',
#   'equations',
#   'stoichiometric',
#   'relationships',
#   'calculate',
#   'product',
#   'reactant',
#   'amounts',
#   'identify',
#   'different',
#   'types',
#   'reactions',
#   'precipitation',
#   'neutralization',
#   'oxidation',
#   'reduction',
#   'predict',
#   'reactions',
#   'thermodynamics',
#   'role',
#   'energy',
#   'enthalpy',
#   'chemical',
#   'reactions',
#   'perform',
#   'thermochemical',
#   'calculations',
#   'concepts',
#   'quantum',
#   'theory',
#   'determine',
#   'electron',
#   'configurations',
#   'atoms',
#   'periodic',
#   'trends',
#   'predictions',
#   'atomic',
#   'properties',
#   'theories',
#   'chemical',
#   'bonding',
#   'determine',
#   'molecular',
#   'geometry',
#   'molecules',
#   'vsepr',
#   'theory',
#   'laws',
#   'kinetic',
#   'molecular',
#   'theory',
#   'processes',
#   'involving',
#   'gases',
#   'explain',
#   'intermolecular',
#   'attractive',
#   'forces',
#   'determine',
#   'properties',
#   'states',
#   'matter',
#   'phase',
#   'behavior',
#   'colligative',
#   'properties',
#   'determining',
#   'characteristics',
#   'solutions',
#   'mindtap',
#   'platform',
#   'seamlessly',
#   'integrates',
#   'content',
#   'assignments',
#   'code',
#   'package',
#   'physical',
#   'area',
#   'bookstores',
#   'alternatively',
#   'code',
#   'purchased',
#   'physical',
#   'directly',
#   'publisher',
#   'link',
#   'blackboard',
#   'sets',
#   'consisting',
#   'questions',
#   'recent',
#   'tutorials',
#   'subjects',
#   'covered',
#   'assigned',
#   'immediately',
#   'prior',
#   'strongly',
#   'encouraged',
#   'assignments',
#   'released',
#   'accepted',
#   'completed',
#   'treated',
#   'adjustment',
#   'completed',
#   'addition',
#   'scored',
#   'changed',
#   'questions',
#   'redone',
#   'multiple',
#   'times',
#   'correct',
#   'answer',
#   'submitted',
#   'guarantee',
#   'passing',
#   'simply',
#   'completing',
#   'completed',
#   'turning',
#   'systems',
#   'clickers',
#   'recitation',
#   'sessions',
#   'details',
#   'clicker',
#   'registration',
#   'determined',
#   'clicker',
#   'device',
#   'clicker',
#   'number',
#   'like',
#   '166d7d',
#   'bring',
#   'clicker',
#   'recitation',
#   'recitation',
#   'points',
#   'awarded',
#   'minimum',
#   'number',
#   'correct',
#   'answers',
#   'number',
#   'questions',
#   'lowest',
#   'recitation',
#   'session',
#   'score',
#   'dropped',
#   'images',
#   'clickers',
#   'midterm',
#   'examinations',
#   'anticipated',
#   'cover',
#   'chapters',
#   'anticipated',
#   'cover',
#   'chapters',
#   'anticipated',
#   'cover',
#   'chapters',
#   'programmable',
#   'scientific',
#   'calculator',
#   'communication',
#   'capabilities',
#   'acceptable',
#   'exams',
#   'proctoring',
#   'method',
#   'examinations',
#   'valid',
#   'reason',
#   'exams',
#   'prorated',
#   '12/10/14',
#   'extra',
#   '12/8/13',
#   '4:30',
#   '7:00pm',
#   'room',
#   'letter',
#   'grades',
#   'tba%',
#   '77-<89',
#   '64-<77',
#   '50-<64',
#   '0-<50',
#   'hours',
#   '10:00',
#   '10:50',
#   '11:00',
#   '11:50',
#   'advance',
#   'know',
#   'coming',
#   'special',
#   'conditions',
#   'special',
#   'arrangements',
#   'order',
#   'requirements',
#   'soon',
#   'possible',
#   'necessary',
#   'arrangements',
#   'verification',
#   'services',
#   'instructors',
#   'allowed',
#   'accommodations',
#   'verification',
#   'services',
#   'provided',
#   'information',
#   'services',
#   'west',
#   'hall',
#   'honesty',
#   'texas',
#   'tech',
#   'foster',
#   'spirit',
#   'honesty',
#   'high',
#   'standard',
#   'attempt',
#   'honestly',
#   'performed',
#   'regarded',
#   'administration',
#   'offense',
#   'renders',
#   'offenders',
#   'liable',
#   'consequences',
#   'possibly',
#   'suspension',
#   'religious',
#   'holy',
#   'intends',
#   'observe',
#   'religious',
#   'holy',
#   'intention',
#   'known',
#   'prior',
#   'absent',
#   'classes',
#   'observance',
#   'religious',
#   'holy',
#   'shall',
#   'allowed',
#   'scheduled',
#   'reasonable',
#   'specific',
#   'natural',
#   'science',
#   'core',
#   'curriculum',
#   'learning',
#   'outcomes',
#   'methods',
#   'expected',
#   'gain',
#   'developing',
#   'following',
#   'learning',
#   'tools',
#   'critical',
#   'thinking',
#   'skills',
#   'gain',
#   'critical',
#   'thinking',
#   'skills',
#   'evaluating',
#   'content',
#   'presented',
#   'lectures',
#   'working',
#   'problems',
#   'methods',
#   'exams',
#   'communication',
#   'skills',
#   'develop',
#   'oral',
#   'communication',
#   'skills',
#   'small',
#   'chemistry',
#   'topics',
#   'written',
#   'communication',
#   'skills',
#   'developed',
#   'assignments',
#   'methods',
#   'empirical',
#   'quantitative',
#   'skills',
#   'reinforce',
#   'empirical',
#   'quantitative',
#   'skills',
#   'working',
#   'mindtap',
#   'participating',
#   'solving',
#   'depth',
#   'fundamental',
#   'current',
#   'topics',
#   'methods',
#   'exams',
#   'teamwork',
#   'strategies',
#   'unclear',
#   'points',
#   'misconceptions',
#   'controversial',
#   'issues',
#   'related',
#   'ethical',
#   'scientific',
#   'aspects',
#   'topical',
#   'issues',
#   'stimulate',
#   'small',
#   'chem',
#   'laboratory',
#   'associated',
#   'required',
#   'core',
#   'main',
#   'teamwork',
#   'practicing',
#   'application',
#   'laboratory',
#   'setting',
#   'conclusion',
#   'assessed',
#   'teamwork',
#   'contribution',
#   'combination',
#   'self',
#   'team',
#   'methods',
#   'small',
#   'assignments',
#   'combined',
#   'self',
#   'team',
#   'technique',
#   'effort',
#   'experimental',
#   'completion',
#   'knowledge',
#   'scientific',
#   'method',
#   'exposed',
#   'historical',
#   'current',
#   'information',
#   'gathering',
#   'methods',
#   'related',
#   'fundamental',
#   'chemical',
#   'principles',
#   'covered',
#   'scientific',
#   'method',
#   'understanding',
#   'world',
#   'limits',
#   'scientific',
#   'method',
#   'methods',
#   'exams',
#   'knowledge',
#   'tools',
#   'methods',
#   'scientific',
#   'inquiry',
#   'technologies',
#   'methodologies',
#   'related',
#   'performance',
#   'chemistry',
#   'indicated',
#   'discussed',
#   'historical',
#   'e.g.',
#   'development',
#   'theories',
#   'atomic',
#   'structure',
#   'topical',
#   'alternative',
#   'renewable',
#   'energy',
#   'methods',
#   'exams',
#   'explain',
#   'theories',
#   'natural',
#   'sciences',
#   'theories',
#   'laws',
#   'e.g.',
#   'difference',
#   'scientific',
#   'theory',
#   'concerning',
#   'atomic',
#   'molecular',
#   'structure',
#   'states',
#   'matter',
#   'thermodynamics',
#   'discussed',
#   'explored',
#   'questions',
#   'methods',
#   'exams',
#   'impact',
#   'natural',
#   'sciences',
#   'social',
#   'issues',
#   'concepts',
#   'learned',
#   'integrated',
#   'societal',
#   'issues',
#   'supplemental',
#   'assignments',
#   'assignments',
#   'particular',
#   'attention',
#   'paid',
#   'ethical',
#   'consequences',
#   'related',
#   'societal',
#   'issues',
#   'methods',
#   'exams',
#   'boards'],
#  ['chem',
#   'introductory',
#   'chemistry',
#   'sections',
#   'spring',
#   'math',
#   'science',
#   'technology',
#   'minnesota',
#   'crookston',
#   '9:00',
#   '9:50',
#   'a.m.',
#   'dowell',
#   'hall',
#   '10:00',
#   '10:50',
#   'a.m.',
#   'dowell',
#   'hall',
#   '1:00',
#   '1:50',
#   'p.m.',
#   'dowell',
#   'hall',
#   '12:00',
#   '2:50',
#   'p.m.',
#   'dowell',
#   'hall',
#   '3:00',
#   '5:50',
#   'p.m.',
#   'dowell',
#   'hall',
#   '2:00',
#   '4:50',
#   'p.m.',
#   'dowell',
#   'hall',
#   '9:00',
#   '11:50',
#   'a.m.',
#   'dowell',
#   'hall',
#   '2:00',
#   '4:50',
#   'p.m.',
#   'dowell',
#   'hall',
#   '5:00',
#   '7:50',
#   'p.m.',
#   'dowell',
#   'hall',
#   'hours',
#   'nancy',
#   'shay',
#   'teaching',
#   'specialist',
#   'dowell',
#   'annex',
#   'minn',
#   'previously',
#   'number',
#   'changed',
#   '12:00',
#   '12:50',
#   'p.m.',
#   'times',
#   'appointment',
#   'problems',
#   'questions',
#   'surface',
#   'asap',
#   'best',
#   'tuesdays',
#   'wednesdays',
#   'thursdays',
#   'check',
#   'messages',
#   'days',
#   'check',
#   'messages',
#   'weekdays',
#   'evening',
#   'early',
#   'morning',
#   'hours',
#   'check',
#   'weekends',
#   'respond',
#   'emails',
#   'hours',
#   'usually',
#   'hours',
#   'typically',
#   'announcements',
#   'notify',
#   'moodle',
#   'quickmail',
#   'needed',
#   'hours',
#   'fully',
#   'respond',
#   'respond',
#   'received',
#   'timeframe',
#   'feedback',
#   'best',
#   'attention',
#   'informative',
#   'subject',
#   'line',
#   'scan',
#   'high',
#   'priority',
#   'items',
#   'emails',
#   'questions',
# ...
#   'chem',
#   'plus',
#   'chem',
#   'chem',
#   'required',
#   'minor',
#   'chem',
#   'chem',
#   'taken',
#   'place',
#   'chem',
#   'hours',
#   'chemistry',
#   'courses',
#   'numbered',
#   'writing',
#   'chem',
#   'designated',
#   'fulfill',
#   'writing',
#   'includes',
#   'multiple',
#   'writing',
#   'projects',
#   'preparation',
#   'professional',
#   'graduate',
#   'year',
#   'chemistry',
#   'professional',
#   'chem',
#   'chem',
#   'considering',
#   'going',
#   'graduate',
#   'program',
#   'chemistry',
#   'consider',
#   'taking',
#   'courses',
#   'minimum',
#   'listed',
#   'interested',
#   'teaching',
#   'education',
#   'secondary',
#   'education',
#   'minor',
#   'requirements',
#   'chemistry',
#   'courses',
#   'chem',
#   'environment',
#   'chemical',
#   'perspective',
#   'hours',
#   'fulfills',
#   'natural',
#   'world',
#   'environment',
#   'emphasis',
#   'relationship',
#   'technology',
#   'surroundings',
#   'laboratory',
#   'field',
#   'studies',
#   'surrounding',
#   'area',
#   'designed',
#   'science',
#   'little',
#   'science',
#   'background',
#   'earn',
#   'earn',
#   'chem',
#   'chem',
#   'essentials',
#   'chemistry',
#   'hours',
#   'fulfills',
#   'natural',
#   'world',
#   'quantitative',
#   'chemistry',
#   'wish',
#   'chemistry',
#   'laboratory',
#   'component',
#   'topics',
#   'chosen',
#   'chemical',
#   'principles',
#   'sequence',
#   'chemistry',
#   'laboratories',
#   'introduce',
#   'chemistry',
#   'skills',
#   'techniques',
#   'intended',
#   'going',
#   'chemistry',
#   'biology',
#   'algebra',
#   'skills',
#   'assumed',
#   'earn',
#   'earn',
#   'chem',
#   'chem',
#   'chemical',
#   'principles',
#   'hours',
#   'fulfills',
#   'natural',
#   'world',
#   'quantitative',
#   'laboratory',
#   'intended',
#   'primarily',
#   'concentrating',
#   'science',
#   'area',
#   'algebra',
#   'skills',
#   'assumed',
#   'earn',
#   'earn',
#   'chem',
#   'chem',
#   'chemical',
#   'principles',
#   'hours',
#   'fulfills',
#   'natural',
#   'world',
#   'quantitative',
#   'prerequisites',
#   'chem',
#   'intended',
#   'primarily',
#   'concentrating',
#   'science',
#   'area',
#   'algebra',
#   'skills',
#   'assumed',
#   'chem',
#   'advanced',
#   'chemical',
#   'principles',
#   'hours',
#   'fulfills',
#   'natural',
#   'world',
#   'quantitative',
#   'faster',
#   'paced',
#   'chemistry',
#   'chem',
#   'chem',
#   'included',
#   'chemical',
#   'knowledge',
#   'competence',
#   'algebra',
#   'assumed',
#   'emphasize',
#   'instruments',
#   'data',
#   'handling',
#   'spreadsheets',
#   'good',
#   'high',
#   'chemistry',
#   'testing',
#   'math',
#   'mathematics',
#   'placement',
#   'order',
#   'year',
#   'chemistry',
#   'required',
#   'professional',
#   'schools',
#   'chem',
#   'addition',
#   'earn',
#   'earn',
#   'chem',
#   'chem',
#   'analytical',
#   'chemistry',
#   'hours',
#   'fulfills',
#   'natural',
#   'world',
#   'prerequisites',
#   'chem',
#   'quantitative',
#   'analysis',
#   'laboratory',
#   'provides',
#   'detailed',
#   'equilibrium',
#   'chemistry',
#   'application',
#   'gravimetry',
#   'titrimetry',
#   'theory',
#   'chromatographic',
#   'separations',
#   'spectroscopic',
#   'detection',
#   'introduced',
#   'chem',
#   'organic',
#   'chemistry',
#   'hours',
#   'fulfills',
#   'natural',
#   'world',
#   'prerequisites',
#   'chem',
#   'sequence',
#   'examines',
#   'structure',
#   'reactivity',
#   'compounds',
#   'containing',
#   'carbon',
#   'topics',
#   'bonding',
#   'nomenclature',
#   'conformations',
#   'stereochemistry',
#   'organic',
#   'acid',
#   'chemistry',
#   'reaction',
#   'mechanism',
#   'reaction',
#   'pathways',
#   'achieved',
#   'reactivity',
#   'aliphatic',
#   'hydrocarbons',
#   'spectroscopic',
#   'identification',
#   'organic',
#   'molecules',
#   'spectroscopy',
#   'examined',
#   'lectures',
#   'chem',
#   'organic',
#   'chemistry',
#   'hours',
#   'prerequisites',
#   'chem',
#   'sequence',
#   'examines',
#   'structure',
#   'reactivity',
#   'compounds',
#   'containing',
#   'carbon',
#   'topics',
#   'reactivity',
#   'aromatic',
#   'hydrocarbons',
#   'molecules',
#   'containing',
#   'carbonyl',
#   'functional',
#   'parallels',
#   'behavior',
#   'compounds',
#   'biomolecules',
#   'illustrated',
#   'emphasis',
#   'placed',
#   'reaction',
#   'mechanisms',
#   'design',
#   'multi',
#   'step',
#   'organic',
#   'syntheses',
#   'lectures',
#   'chem',
#   'biochemistry',
#   'hours',
#   'prerequisites',
#   'chem',
#   'chem',
#   'chemistry',
#   'classes',
#   'biological',
#   'molecules',
#   'proteins',
#   'sugars',
#   'lipids',
#   'nucleic',
#   'acids',
#   'relationship',
#   'functional',
#   'roles',
#   'molecules',
#   'structure',
#   'reactivity',
#   'examined',
#   'chemical',
#   'principles',
#   'mastered',
#   'courses',
#   'chemistry',
#   'semesters',
#   'organic',
#   'chemistry',
#   'fulfill',
#   'biochemistry',
#   'typical',
#   'health',
#   'professional',
#   'programs',
#   'chem',
#   'instrumental',
#   'methods',
#   'spectroscopic',
#   'techniques',
#   'hours',
#   'prerequisites',
#   'chem',
#   'detailed',
#   'look',
#   'instrumentation',
#   'applications',
#   'optical',
#   'spectroscopy',
#   'associated',
#   'chemical',
#   'analyses',
#   'topics',
#   'molecular',
#   'atomic',
#   'absorption',
#   'fluorescence',
#   'spectrometries',
#   'selected',
#   'advanced',
#   'spectroscopic',
#   'techniques',
#   'chem',
#   'instructional',
#   'methods',
#   'separations',
#   'electrochemistry',
#   'hours',
#   'prerequisites',
#   'chem',
#   'chem',
#   'detailed',
#   'look',
#   'methods',
#   'separation',
#   'electroanalytical',
#   'techniques',
#   'including',
#   'hplc',
#   'potentiometry',
#   'amperometry',
#   'voltammetry',
#   'chem',
#   'biochemistry',
#   'laboratory',
#   'hours',
#   'prerequisites',
#   'chem',
#   'following',
#   'chem',
#   'chem',
#   'recommended',
#   'laboratory',
#   'isolation',
#   'analysis',
#   'biological',
#   'molecules',
#   'techniques',
#   'employed',
#   'cell',
#   'culture',
#   'protein',
#   'purification',
#   'fluorescent',
#   'tags',
#   'immunochemical',
#   'methods',
#   'analysis',
#   'chem',
#   'chemical',
#   'kinetics',
#   'hours',
#   'prerequisites',
#   'chem',
#   'math',
#   'area',
#   'chemistry',
#   'involving',
#   'rates',
#   'chemical',
#   'reactions',
#   'occur',
#   'topics',
#   'classical',
#   'kinetics',
#   'kinetics',
#   'fast',
#   'reactions',
#   'enzyme',
#   'kinetics',
#   'chem',
#   'quantum',
#   'chemistry',
#   'spectroscopy',
#   'hours',
#   'prerequisites',
#   'math',
#   'phys',
#   'phys',
#   'phys',
#   'formalism',
#   'quantum',
#   'mechanics',
#   'core',
#   'quantum',
#   'mechanical',
#   'models',
#   'particle',
#   'harmonic',
#   'oscillator',
#   'rigid',
#   'rotor',
#   'hydrogen',
#   'atom',
#   'applications',
#   'models',
#   'describe',
#   'types',
#   'spectroscopy',
#   'chemical',
#   'systems',
#   'chem',
#   'thermodynamics',
#   'hours',
#   'prerequisites',
#   'chem',
#   'chem',
#   'math',
#   'phys',
#   'phys',
#   'phys',
#   'phys',
#   'mathematical',
#   'treatment',
#   'fundamental',
#   'laws',
#   'thermodynamics',
#   'laws',
#   'govern',
#   'chemical',
#   'physical',
#   'changes',
#   'chem',
#   'spectroscopy',
#   'separations',
#   'hours',
#   'prerequisites',
#   'chem',
#   'chem',
#   'laboratory',
#   'types',
#   'spectroscopy',
#   'separation',
#   'techniques',
#   'chemistry',
#   'laboratory',
#   'techniques',
#   'fluorescence',
#   'spectroscopy',
#   'liquid',
#   'phase',
#   'chromatography',
#   'chem',
#   'thermodynamics',
#   'kinetics',
#   'laboratory',
#   'hours',
#   'prerequisites',
#   'chem',
#   'chem',
#   'chem',
#   'recommended',
#   'laboratory',
#   'energetics',
#   'rates',
#   'chemical',
#   'reactions',
#   'chem',
#   'polymer',
#   'chemistry',
#   'hours',
#   'prerequisites',
#   'chem',
#   'polymer',
#   'science',
#   'examines',
#   'synthesis',
#   'characterization',
#   'properties',
#   'macromolecules',
#   'emphasis',
#   'placed',
#   'mechanisms',
#   'polymerization',
#   'stereochemistry',
#   'monomer',
#   'enchainment',
#   'determination',
#   'molar',
#   'mass',
#   'distributions',
#   'thermal',
#   'properties',
#   'bulk',
#   'polymers',
#   'offered',
#   'alternate',
#   'years',
#   'chem',
#   'organometallic',
#   'chemistry',
#   'hours',
#   'prerequisites',
#   'chem',
#   'structure',
#   'reactivity',
#   'compounds',
#   'carbon',
#   'metal',
#   'covalent',
#   'bonds',
#   'emphasis',
#   'placed',
#   ...],
#  ['objectives',
#   'theories',
#   'principles',
#   'applications',
#   'modern',
#   'instrumental',
#   'methods',
#   'including',
#   'spectroscopic',
#   'surface',
#   'characterization',
#   'thermal',
#   'electroanalytical',
#   'chromatographic',
#   'techniques',
#   'laboratory',
#   'applications',
#   'instrumental',
#   'methods',
#   'observe',
#   'operation',
#   'instruments',
#   'currently',
#   'improve',
#   'understanding',
#   'statistical',
#   'methods',
#   'data',
#   'application',
#   'quantitative',
#   'chemical',
#   'analysis',
#   'outcomes',
#   'acquire',
#   'detailed',
#   'understanding',
#   'principles',
#   'operation',
#   'modern',
#   'analytical',
#   'instrumentation',
#   'demonstrate',
#   'critical',
#   'thinking',
#   'quantitative',
#   'reasoning',
#   'scientific',
#   'knowledge',
#   'related',
#   'wide',
#   'variety',
#   'choices',
#   'instrumental',
#   'methods',
#   'solve',
#   'analytical',
#   'problems',
#   'acquire',
#   'advanced',
#   'laboratory',
#   'skills',
#   'associated',
#   'collection',
#   'handling',
#   'analytical',
#   'data',
#   'demonstrate',
#   'competence',
#   'writing',
#   'scientific',
#   'reports',
#   'required',
#   'following',
#   'books',
#   'supplies',
#   'bookstore',
#   'principles',
#   'instrumental',
#   'analysis',
#   'douglas',
#   'skoog',
#   'james',
#   'holler',
#   'stanley',
#   'crouch',
#   'edition',
#   'brooks',
#   'cole',
#   'thomson',
#   'learning',
#   'required',
#   'che-302',
#   'instrumental',
#   'analysis',
#   'laboratory',
#   'manual',
#   'cedar',
#   'crest',
#   'edition',
#   'laboratory',
#   'notebook',
#   'scientific',
#   'hand',
#   'calculator',
#   'protection',
#   'safety',
#   'glasses',
#   'goggles',
#   'times',
#   '9:30',
#   '10:45',
#   'oberkotter',
#   'oberkotter',
#   'extension',
#   'x3495',
#   'hours',
#   'tues',
#   'thurs.8:00',
#   '9:00',
#   'tues.11:00',
#   'appointment',
#   'grading',
#   'divided',
#   'portions',
#   'laboratory',
#   'portion',
#   'constitutes',
#   'overall',
#   'laboratory',
#   'portion',
#   'constitutes',
#   'letter',
#   'entire',
#   'laboratory',
#   'portions',
#   'earn',
#   'passing',
#   'based',
#   'exams',
#   'sets',
#   'comprehensive',
#   'lowest',
#   'dropped',
#   'value',
#   'examinations',
#   'sets',
#   'average',
#   'computed',
#   'follows',
#   'letter',
#   'awarded',
#   'according',
#   'following',
#   'scale',
#   'policies',
#   'mandatory',
#   'taken',
#   'impact',
#   'earn',
#   'attending',
#   'participating',
#   'days',
#   'days',
#   'mandatory',
#   'important',
#   'responsibility',
#   'prevents',
#   'attending',
#   'testing',
#   'inform',
#   'advance',
#   'arrangements',
#   'alternate',
#   'testing',
#   'policy',
#   'followed',
#   'given',
#   'missed',
#   'advance',
#   'notice',
#   'given',
#   'discretion',
#   'instances',
#   'valid',
#   'written',
#   'excuse',
#   'required',
#   'doctor',
#   'nurse',
#   'case',
#   'illness',
#   'dean',
#   'case',
#   'family',
#   'emergency',
#   'giving',
#   'satisfactory',
#   'reasonable',
#   'explanation',
#   'missed',
#   'procedures',
#   'followed',
#   'given',
#   'missed',
#   'obtaining',
#   'assistance',
#   'hesitate',
#   'seek',
#   'assistance',
#   'concerning',
#   'lectures',
#   'assignments',
#   'grading',
#   'scheduled',
#   'hours',
#   'arrangements',
#   'alternative',
#   'convenience',
#   'extra',
#   'policy',
#   'extra',
#   'opportunities',
#   'entire',
#   'offered',
#   'discretion',
#   'learning',
#   'disabilities',
#   'supports',
#   'cedar',
#   'crest',
#   'policy',
#   'learning',
#   'disabilities',
#   'follows',
#   'documented',
#   'disabilities',
#   'accommodations',
#   'needs',
#   'professors',
#   'weeks',
#   'disabilities',
#   'wish',
#   'request',
#   'accommodations',
#   'advising',
#   'chemical',
#   'physical',
#   'science',
#   'departmental',
#   'policy',
#   'electronic',
#   'communication',
#   'devices',
#   'departmental',
#   'policy',
#   'communication',
#   'devices',
#   'cell',
#   'phones',
#   'pagers',
#   'blackberries',
#   'ipods',
#   'turned',
#   'vibrate',
#   'cell',
#   'phones',
#   'vibrate',
#   'accept',
#   'emergency',
#   'notices',
#   'laptop',
#   'computers',
#   'taking',
#   'purposes',
#   'recording',
#   'device',
#   'including',
#   'smart',
#   'requires',
#   'permission',
#   'cell',
#   'messaging',
#   'playing',
#   'entertainment',
#   'media',
#   'period',
#   'strictly',
#   'forbidden',
#   'violators',
#   'dismissed',
#   'conversations',
#   'voice',
#   'message',
#   'honor',
#   'philosophy',
#   'cedar',
#   'crest',
#   'honor',
#   'philosophy',
#   'states',
#   'uphold',
#   'community',
#   'standards',
#   'social',
#   'behavior',
#   'order',
#   'preserve',
#   'learning',
#   'environment',
#   'dedicated',
#   'personal',
#   'excellence',
#   'upholding',
#   'community',
#   'standards',
#   'matter',
#   'personal',
#   'honor',
#   'individuals',
#   'accept',
#   'honor',
#   'membership',
#   'cedar',
#   'crest',
#   'community',
#   'scholars',
#   'pledge',
#   'accept',
#   'responsibility',
#   'actions',
#   'social',
#   'situations',
#   'effect',
#   'actions',
#   'members',
#   'community',
#   'expects',
#   'abide',
#   'honor',
#   'code',
#   'honor',
#   'code',
#   'applies',
#   'activities',
#   'associated',
#   'realize',
#   'honor',
#   'code',
#   'important',
#   'aspect',
#   'educational',
#   'process',
#   'cedar',
#   'crest',
#   'cedar',
#   'crest',
#   'administration',
#   'following',
#   'statement',
#   'concerning',
#   'protocol',
#   'behavior',
#   'implicit',
#   'cedar',
#   'crest',
#   'honor',
#   'code',
#   'behavior',
#   'defined',
#   'guided',
#   'protection',
#   'rights',
#   'courteous',
#   'respectful',
#   'environment',
#   'environment',
#   'free',
#   'distractions',
#   'arrivals',
#   'early',
#   'departures',
#   'inappropriate',
#   'conversations',
#   'behaviors',
#   'disrupt',
#   'compromise',
#   'cedar',
#   'crest',
#   'education',
#   'sure',
#   'place',
#   'cell',
#   'phones',
#   'pagers',
#   'vibrate',
#   'mode',
#   'times',
#   'community',
#   'standards',
#   'ethics',
#   'remain',
#   'steadfast',
#   'withstanding',
#   'technological',
#   'change',
#   'cedar',
#   'crest',
#   'standards',
#   'including',
#   'limited',
#   'handwritten',
#   'computer',
#   'generated',
#   'documents',
#   'video',
#   'audio',
#   'recordings',
#   'telecommunications',
#   'cedar',
#   'crest',
#   'shall',
#   'adhere',
#   'rules',
#   'acknowledging',
#   'outside',
#   'sources',
#   'defined',
#   'plagiarizing',
#   'misrepresenting',
#   'intellectual',
#   'property',
#   'seeks',
#   'receives',
#   'converse',
#   'inappropriate',
#   'materials',
#   'authorized',
#   'instructions',
#   'situation',
#   'environment',
#   'including',
#   'taking',
#   'examinations',
#   'laboratory',
#   'procedures',
#   'preparation',
#   'properly',
#   'respectfully',
#   'facilities',
#   'resources',
#   'including',
#   'library',
#   'computing',
#   'resources',
#   'ensure',
#   'resources',
#   'effectively',
#   'shared',
#   'members',
#   'community',
#   'abide',
#   'cedar',
#   'crest',
#   'computer',
#   'policy',
#   'perceives',
#   'violation',
#   'standards',
#   'unable',
#   'resolve',
#   'chair',
#   'assistance',
#   'consultation',
#   'chair',
#   'provost',
#   'policy',
#   'deal',
#   'violations',
#   'standards',
#   'awarding',
#   'chronological',
#   'plan',
#   'lists',
#   'dates',
#   'topics',
#   'constitute',
#   'lectures',
#   'pertaining',
#   'summary',
#   'testing',
#   'content',
#   'provided',
#   'modified',
#   'needed',
#   'testing',
#   'summary',
#   'included',
#   'tues',
#   'chapters',
#   'thur',
#   'chapters',
#   'thur',
#   'chapters',
#   'tues',
#   'chapters',
#   'comprehensive',
#   'topics',
#   'subject',
#   'sets',
#   'basics',
#   'instrumental',
#   'analysis',
#   'calibration',
#   'selecting',
#   'method',
#   'signals',
#   'noise',
#   'spectroscopy',
#   'quantum',
#   'mechanical',
#   'properties',
#   'radiation',
#   'components',
#   'optical',
#   'instruments',
#   'atomic',
#   'spectroscopy',
#   'atomic',
#   'absorption',
#   'spectroscopy',
#   'atomic',
#   'emission',
#   'spectroscopy',
#   'pp.254',
#   'spectroscopy',
#   'pp.336',
#   'applications',
#   'spectroscopy',
#   'pp.367',
#   'spring',
#   'break',
#   'luminescence',
#   'spectroscopy',
#   'pp.399',
#   'infrared',
#   'spectroscopy',
#   'pp.430',
#   'applications',
#   'infrared',
#   'spectroscopy',
#   'pp.455',
#   'spectroscopy',
#   'pp.498',
#   'theory',
#   'chemical',
#   'shift',
#   'spectroscopy',
#   'pp.513',
#   'mass',
#   'spectrometry',
#   'pp.550',
#   'separation',
#   'science',
#   'pp.761',
#   'withdrawal',
#   'chromatography',
#   'pp.788',
#   'high',
#   'performance',
#   'liquid',
#   'chromatography',
#   'pp.816',
#   'capillary',
#   'electrophoresis',
#   'pp.867',
#   'electroanalytical',
#   'chemistry',
#   'pp.628',
#   'calculation',
#   'cell',
#   'potentials',
#   'pp.645',
#   'che-302',
#   'instrumental',
#   'analysis',
#   'che-302',
#   'thomas',
#   'brettell',
#   'spring']]

# %%
all_texts = []

# %%
for field in field_texts:
    for text in field_texts[field]:
        all_texts.append(text)

# %%
len(all_texts)
# Out:
# 8045

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models.word2vec import Word2Vec
from gensim.models import KeyedVectors
from gensim.models import TfidfModel
import gensim
from gensim.corpora import Dictionary
import numpy as np

# %%
def create_model(corpus):
    model = Doc2Vec(vector_size=100, min_count=5, epochs=40)
    i = 0
    train_corpus = []
    for doc in corpus:
        # process doc more?
        train_corpus.append(TaggedDocument(doc, [i]))
        i += 1
    model.build_vocab(train_corpus)
    model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs)
    return model

# %%
model = create_model(all_texts)

# %%
import random

# %%
within_differences = []

# %%
between_differences = []

# %%
from scipy.spatial import distance

# %%
while(len(between_differences) < 1000):
    field_1, field_2 = random.sample(list(field_texts.keys()), 2)
    if len(field_texts[field_1]) < 2 or len(field_texts[field_2]) < 2:
        continue
    text_1, text_2 = random.sample(field_texts[field_1], 2)
    text_3 = random.sample(field_texts[field_2], 1)[0]
    vec_1 = model.infer_vector(text_1)
    vec_2 = model.infer_vector(text_2)
    vec_3 = model.infer_vector(text_3)
    within_difference = distance.cosine(vec_1, vec_2)
    between_difference = distance.cosine(vec_2, vec_3)
    within_differences.append(within_difference)
    between_differences.append(between_difference)

# %%
def statistics(differences):
    sorted_differences = sorted(differences)
    mean_differences = np.mean(sorted_differences)
    variance_differences = np.var(differences)
    Bs = []
    
    for i in range(0, len(differences)):
        B = np.sqrt(len(differences))
        Bs.append(B)
    upper_interval = mean_differences - (((Bs[len(differences) -1]) * sorted_differences[len(differences)-1]) / len(differences))
    lower_interval = mean_differences - (((Bs[1]) * sorted_differences[1]) / len(differences))
    return [(lower_interval, upper_interval), (sorted_differences[0], sorted_differences[-1]), variance_differences]

# %%
statistics(between_differences)
# Out:
# [(0.8268901950516041, 0.8049127740839689),
#  (0.3904539942741394, 1.1475856453180313),
#  0.014105193191905199]

# %%
statistics(within_differences)
# Out:
# [(0.6477223068687135, 0.6163529324926518),
#  (0.002533257007598877, 1.0305310152471066),
#  0.022848953755698218]

# %%
from scipy.stats import ks_2samp

# %%
ks_2samp(within_differences, between_differences)
# Out:
# KstestResult(statistic=0.539, pvalue=1.774876169162964e-133)
