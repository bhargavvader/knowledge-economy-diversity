# %% [markdown]
# ### Meta data for Syllabi
#
# This notebook explores the syllabi data to see how the texts can be cleaned, while also storing meta data to a file. This notebook should be converted to a script when running on the full data.

# %%
from json import JSONDecoder, JSONDecodeError
import re
import os
from collections import Counter
from datetime import datetime

# %%
maybe = ["service", "administration", 'process']

# %%
my_stop_words = ['papers', 'paper', 'discussion', 'complete', 'require', 'time', 'quiz', 'attendance',
 'study', 'instructor', 'examination', 'course', 'student', 'students', 'syllabus', 'work', 'class', 'assignment',
 'requiring', 'requirement', 'credit', 'include', 'grade', 'week', 'professor', 'exam', 'final', 'credits', 'essay',
 'assessment', '•', 'prerequisite', 'book', 'textbook', 'withdraw', 'homework', 'hyperlink',
 'mailto:', 'exercise', '%', 'drop', 'withdrawl', 'pass', 'fail', 'classroom','campus','catalog',
 'unit', 'chapter', 'sunday', 'monday', 'tuesday', 'wednesday','thursday','friday','saturday','january',
 'february', 'march', 'april', 'may', 'june','july', 'august','september','october','november','december',
 'project','participation','semeseter', 'trimester','quarter','academic',
 'point', 'provide','activity', 'learn','date','office','hour','page', 'lecture',
 'review','lesson','disability','contact','meeting','meet','deadline','submit','integrity','dishonesty',
    'plagiarism', 'able', 'prepare', 'response', 'study', 'department',
 'cheat','report','submit','faculty','university','semester','presentation', 'summer','practicum',
 'instruction', 'generally', 'site', 'description', 'detail', 'unpaid', 'involve', 'college',
 'group', 'problem', 'support', 'section', 'schedule', 'available', 'term', 'late',
 'email', 'system', 'and/or','absence', 'introduction', 'write', 'read', 'test', 
 'topic', 'need', 'online','skill','note','resource', 'expect', 'post',  'question', 'material', 'follow',
 'help', 'apply', 'receive', 'base','practice','school','issue', 'center',
 'fall', 'assign', 'general', 'outcome', 'find', 'basic', 'total', 'evaluation', 'give', 'text',
 'learn', 'grade', 'require', 'point', 'hour', 'include', 'follow',
  'question', 'service', 'provide', 'course', 'requirement', 'exam', 'individual', 'expect', 
 'reading', 'give', 'access', 'experience', 'relate', 'discuss', 'activity', 'major',
    'result', 'level', 'form', 'appropriate', 'complete', 'assign', 'class','present', 'accommodation',
 'issue', 'well', 'think', 'list', 'phone', 'understand',  
    'quiz', 'miss', 'problem', 'right', 'degree', 'begin', 'teach', 'conduct', 'take', 'additional' 
    ]

# %%
NOT_WHITESPACE = re.compile(r'[^\s]')
def decode_stacked(document, pos=0, decoder=JSONDecoder()):
    while True:
        match = NOT_WHITESPACE.search(document, pos)
        if not match:
            return
        pos = match.start()

        try:
            obj, pos = decoder.raw_decode(document, pos)
        except JSONDecodeError:
            # do something sensible if there's some error
            raise
        yield obj

# %%
texts = []
deformatted_texts = []
states = []
cities = []
names = []
fields = []

# %%
i = 0

# %%
meta_data = {}

# %%
for filename in os.listdir("../openSyReal/"):
    i += 1
    if i > 3:
        break
    if filename.endswith(".json"): #Added try before countrycode and encoding argument
        with open("../openSyReal/" + filename, encoding = 'utf-8') as f:
            for line in f:
                for jsonfile in decode_stacked(line):
                    try:
                        if jsonfile['grid_country_code'] == 'US':
                            # texts.append(jsonfile['text'])
                            try:
                                name = jsonfile['NAME']
                                # names.append(name)
                            except KeyError:
                                name = None
                                # names.append(None)

                            try:
                                city = jsonfile['CITY']
                                # cities.append(city)
                            except KeyError:
                                city = None
                                # cities.append(None)
                            try:
                                state = jsonfile['STABBR']
                                # states.append(state)
                            except KeyError:
                                city = None
                                #states.append(None)
                            try:
                                field = jsonfile['field_name']
                                # fields.append(field)
                            except KeyError:
                                field = None
                                #fields.append(None)
                            try:
                                year = jsonfile['year']
                                # years.append(year)
                            except KeyError:
                                year = None
                                #years.append(None)
                            
                            if name is not None and (name, year) not in meta_data:
                                meta_data[(name, year)] = {}
                            if name is not None and (name, year) in meta_data and field not in meta_data[(name, year)]:
                                meta_data[(name, year)][field] = 0
                            if name is not None and (name, year) in meta_data and field in meta_data[(name, year)]:
                                meta_data[(name, year)][field] += 1
                    except:
                        pass

# %%
meta_data
# Out:
# {('Angelo State University',
#   2013): {'Business, Management, and Related Support Services.': 1, 'Mathematics/Applied Mathematics': 1, 'Accounting and Related Services.': 1, 'Rhetoric and Composition/Writing Studies.': 1, 'Psychology, General/Other.': 1, 'Nursing': 1, 'Parks, Recreation, Leisure, and Fitness Studies.': 1},
#  ('University of Mississippi', 2013): {'Mathematics/Applied Mathematics': 1},
#  ('Tufts University', 2017): {'Computer and Information Sciences.': 2},
#  ('Foothill College', 2017): {'Psychology, General/Other.': 1,
#   'Basic Computer Skills.': 1,
#   'Fine and Studio Arts.': 1},
#  ('University of Georgia', 2011): {'Journalism.': 2,
#   'Statistics.': 1,
#   'Chemistry.': 1,
#   'Computer, Network, and Technology Support Services.': 1,
#   'Marketing.': 1,
#   'Psychology, General/Other.': 1,
#   'Nursing': 1,
#   'Accounting and Related Services.': 1,
#   'Architecture and Related Services.': 1,
#   'Education.': 3,
#   'Philosophy.': 1,
#   'Clinical, Counseling and Applied Psychology.': 1},
#  ('Kean University', 2012): {'Engineering.': 1},
#  ('Jackson College', 2017): {'Anatomy.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Psychology, General/Other.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1},
#  ('University of Florida',
#   1970): {'English Language and Literature/Letters': 1},
#  ('The University of Alabama', 2013): {'Computer and Information Sciences.': 2,
#   'Rhetoric and Composition/Writing Studies.': 3,
#   'Music.': 2,
#   'Atmospheric Sciences and Meteorology.': 6,
#   'History.': 4,
#   'Sociology': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Communications and Media Studies, General/Other.': 1,
#   'Design and Applied Arts.': 1,
#   'Fine and Studio Arts.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Social Work.': 1,
#   'English Language and Literature/Letters': 1},
#  ('Lansing Community College', 2016): {'Mathematics/Applied Mathematics': 6,
#   'Health and Medical Administrative Services.': 1,
#   'Computer and Information Sciences.': 3,
#   'Fire Protection.': 2,
#   'Speech Communication and Rhetoric.': 2,
#   'Economics.': 2,
#   'Music.': 3,
#   'Mechanic and Repair Technologies/Technicians.': 4,
#   'Political Science, Government, International Relations and National Security Studies.': 2,
#   'Statistics.': 1,
#   'Rhetoric and Composition/Writing Studies.': 5,
#   'Construction Trades.': 3,
#   'Fine and Studio Arts.': 3,
#   'American Sign Language.': 3,
#   'Social Work.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 2,
#   'Anatomy.': 2,
#   'Business, Management, and Related Support Services.': 3,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 3,
#   'Marketing.': 1,
#   'English Language and Literature/Letters': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 6,
#   'Natural Resources and Conservation.': 1,
#   'Accounting and Related Services.': 1,
#   'Film/Video and Photographic Arts.': 2,
#   'Computer, Network, and Technology Support Services.': 2,
#   'Physics.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Chemistry.': 2,
#   'Psychology, General/Other.': 2,
#   'Education.': 1,
#   'Basic Skills and Developmental/Remedial/High School Level Education': 1,
#   'Drama/Theatre Arts and Stagecraft.': 1},
#  ('New Mexico Junior College', 2018): {'Economics.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1},
#  ('University of West Georgia', 2013): {'Legal Professions and Studies.': 1,
#   'Education.': 2,
#   'Economics.': 1,
#   'English Language and Literature/Letters': 1},
#  ('Park University',
#   2016): {'Parks, Recreation, Leisure, and Fitness Studies.': 2, 'Business, Management, and Related Support Services.': 6, 'Criminal Justice and Corrections.': 1, 'Rhetoric and Composition/Writing Studies.': 1, 'Psychology, General/Other.': 1, 'Speech Communication and Rhetoric.': 1, 'Economics.': 1},
#  ('University of Florida', None): {'Speech Communication and Rhetoric.': 1,
#   'Geological and Earth Sciences/Geosciences.': 1,
#   'Education.': 1,
#   'Communications and Media Studies, General/Other.': 1},
#  ('University of North Carolina at Chapel Hill', 2004): {'Library Science.': 1,
#   'Mathematics/Applied Mathematics': 1},
#  ('Stephen F Austin State University', 2013): {'Statistics.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 2,
#   'Homeland Security.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Education.': 4,
#   'Geological and Earth Sciences/Geosciences.': 1,
#   'Anthropology.': 1,
#   'Nursing': 1,
#   'Speech Communication and Rhetoric.': 1,
#   'History.': 2,
#   'Business, Management, and Related Support Services.': 1,
#   'Geography and Cartography.': 1,
#   'Journalism.': 1,
#   'Economics.': 1,
#   'American Sign Language.': 1,
#   'Music.': 1},
#  ('Cumberland County College', None): {'Music.': 1,
#   'Computer, Network, and Technology Support Services.': 1,
#   'Engineering.': 1,
#   'English Language and Literature/Letters': 1,
#   'Anatomy.': 1},
#  ('Excelsior College', 2018): {'Homeland Security.': 1,
#   'Criminal Justice and Corrections.': 1,
#   'Education.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Liberal Arts and Sciences, General Studies and Humanities.': 1,
#   'Health and Medical Administrative Services.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 3,
#   'Mathematics/Applied Mathematics': 1},
#  ('Galveston College', 2017): {'Statistics.': 1,
#   'History.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 2,
#   'Anatomy.': 2,
#   'Nursing': 2},
#  ('Kenyon College', 2004): {'Physics.': 1},
#  ('The University of Alabama', 2010): {'History.': 3,
#   'Communications and Media Studies, General/Other.': 1,
#   'Statistics.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Basic Computer Skills.': 1,
#   'German Language and Literature.': 1,
#   'Communication Disorders Sciences and Services.': 1,
#   'Family and Consumer Sciences/Human Sciences.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1},
#  ('Lewis and Clark Community College', None): {'Nursing': 2,
#   'Music.': 2,
#   'Dentistry': 2,
#   'Education.': 2,
#   'Communications and Media Studies, General/Other.': 2,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Basic Computer Skills.': 1},
#  ('North Seattle College', 2016): {'Physics.': 1},
#  ('Houston Community College', 2007): {'Mathematics/Applied Mathematics': 4,
#   'Psychology, General/Other.': 1,
#   'Fine and Studio Arts.': 2,
#   'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Statistics.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Sociology': 1},
#  ('Texas A & M University-Commerce', 2012): {'Education.': 1,
#   'English Language and Literature/Letters': 1,
#   'Statistics.': 1,
#   'Music.': 1,
#   'Psychology, General/Other.': 1,
#   'Accounting and Related Services.': 1},
#  ('University of Maryland-College Park', 2014): {'Philosophy.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1},
#  ('Clemson University', 2013): {'Geography and Cartography.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'History.': 1,
#   'Engineering.': 4,
#   'Statistics.': 1,
#   'Psychology, General/Other.': 1,
#   'Mathematics/Applied Mathematics': 4,
#   'Agriculture, Agriculture Operations, and Related Sciences.': 3,
#   'Education.': 1,
#   'Philosophy.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Computer and Information Sciences.': 1},
#  ('Brandeis University',
#   2014): {'Business, Management, and Related Support Services.': 2},
#  ('The University of Montana',
#   2013): {'Military Science, Leadership, Operational Art, Applied Science, and Technologies': 1,
#   'Fine and Studio Arts.': 1,
#   'Music.': 2,
#   'Natural Resources and Conservation.': 1},
#  ('Western Kentucky University', 2014): {'Education.': 1,
#   'Statistics.': 1,
#   'Dance.': 1,
#   'Research and Experimental Psychology.': 1,
#   'Economics.': 1,
#   'English Language and Literature/Letters': 1,
#   'History.': 1,
#   'Communications and Media Studies, General/Other.': 1,
#   'Architecture and Related Services.': 1,
#   'Religion/Religious Studies.': 1,
#   'Business, Management, and Related Support Services.': 2,
#   'Physics.': 1,
#   'Geography and Cartography.': 2,
#   'Nursing': 1},
#  ('Iowa Western Community College',
#   None): {'Spanish Language and Literature.': 1},
#  ('Tulane University of Louisiana', None): {'Fine and Studio Arts.': 1,
#   'Drama/Theatre Arts and Stagecraft.': 1},
#  ('Brigham Young University-Provo', 2012): {'History.': 1},
#  ('University of Denver', 2014): {'Psychology, General/Other.': 1},
#  ('The University of Alabama', 2014): {'Education.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 2,
#   'Atmospheric Sciences and Meteorology.': 13,
#   'Rhetoric and Composition/Writing Studies.': 2,
#   'History.': 1,
#   'Family and Consumer Sciences/Human Sciences.': 1,
#   'Psychology, General/Other.': 1,
#   'Physics.': 1,
#   'Communications and Media Studies, General/Other.': 1,
#   'Engineering.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1},
#  ('Ithaca College', 2005): {'Legal Professions and Studies.': 1},
#  ('Windward Community College', 2017): {'Psychology, General/Other.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Computer and Information Sciences.': 2},
#  ('Santa Rosa Junior College',
#   2004): {'Agriculture, Agriculture Operations, and Related Sciences.': 1, 'Nursing': 1},
#  ('University of Maryland-University College',
#   2017): {'Rhetoric and Composition/Writing Studies.': 16, 'Business, Management, and Related Support Services.': 35, 'Homeland Security.': 4, 'Economics.': 4, 'Atmospheric Sciences and Meteorology.': 1, 'Legal Professions and Studies.': 2, 'Japanese Language and Literature.': 2, 'Computer and Information Sciences.': 8, 'Computer, Network, and Technology Support Services.': 12, 'Music.': 1, 'Clinical, Counseling and Applied Psychology.': 1, 'Biological and Biomedical Sciences, General/Other.': 10, 'Speech Communication and Rhetoric.': 1, 'English Language and Literature/Letters': 7, 'Job-Seeking and Career Skills': 3, 'Natural Resources and Conservation.': 2, 'Accounting and Related Services.': 6, 'Sociology': 2, 'History.': 7, 'Health and Medical Administrative Services.': 3, 'Political Science, Government, International Relations and National Security Studies.': 4, 'Fine and Studio Arts.': 2, 'Library Science.': 2, 'Criminal Justice and Corrections.': 8, 'Basic Computer Skills.': 2, 'Geological and Earth Sciences/Geosciences.': 2, 'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Statistics.': 4, 'Anthropology.': 1, 'Public Health.': 1, 'Psychology, General/Other.': 3, 'Mathematics/Applied Mathematics': 5, 'Education.': 5, 'Physics.': 1, 'Foods, Nutrition, and Related Services.': 2, 'German Language and Literature.': 2, 'Liberal Arts and Sciences, General Studies and Humanities.': 3, 'Marketing.': 1, 'Social Work.': 1, 'Interpersonal and Social Skills.': 1, 'Fire Protection.': 1, 'Communications and Media Studies, General/Other.': 1},
#  ('University of Georgia', 2013): {'Sociology': 1,
#   'Psychology, General/Other.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Natural Resources and Conservation.': 2,
#   'Engineering.': 2,
#   'Computer and Information Sciences.': 1,
#   'Education.': 2,
#   'Film/Video and Photographic Arts.': 1,
#   'Statistics.': 1,
#   'Clinical, Counseling and Applied Psychology.': 1,
#   'Dance.': 1,
#   'Classics and Classical Languages, Literatures, and Linguistics.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Accounting and Related Services.': 1},
#  ('Santa Rosa Junior College',
#   2006): {'Medicine and Health Professions, General': 1, 'Mechanic and Repair Technologies/Technicians.': 1},
#  ('Oklahoma State University Institute of Technology',
#   2016): {'Mechanic and Repair Technologies/Technicians.': 1},
#  ('University of Southern California',
#   2017): {'Film/Video and Photographic Arts.': 1,
#   'Journalism.': 1,
#   'Engineering.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Social Work.': 1,
#   'Design and Applied Arts.': 1},
#  ('South Plains College', 2012): {'Music.': 1,
#   'Chemistry.': 1,
#   'History.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 1,
#   'Psychology, General/Other.': 1,
#   'Basic Computer Skills.': 1,
#   'Fine and Studio Arts.': 1},
#  ('McLennan Community College', 2017): {'History.': 1,
#   'Criminology.': 1,
#   'Computer and Information Sciences.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Accounting and Related Services.': 1,
#   'Fine and Studio Arts.': 1,
#   'English Language and Literature/Letters': 2,
#   'Geological and Earth Sciences/Geosciences.': 1,
#   'Sociology': 1,
#   'Rhetoric and Composition/Writing Studies.': 1},
#  ('San Jose State University', 2018): {'History.': 1,
#   'Rhetoric and Composition/Writing Studies.': 2,
#   'Liberal Arts and Sciences, General Studies and Humanities.': 1},
#  ('University of North Carolina at Greensboro',
#   2005): {'Rhetoric and Composition/Writing Studies.': 1, 'English Language and Literature/Letters': 1},
#  ('Wayne State University', 2007): {'Computer and Information Sciences.': 1},
#  ('Asbury Theological Seminary',
#   2001): {'Theology and Religious Vocations.': 1},
#  ('The University of Texas at San Antonio', 2015): {'Sociology': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Construction Trades.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Criminal Justice and Corrections.': 1,
#   'Spanish Language and Literature.': 1,
#   'Physics.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1},
#  ('University of Maryland-University College',
#   2015): {'Biological and Biomedical Sciences, General/Other.': 6, 'Computer, Network, and Technology Support Services.': 13, 'Mathematics/Applied Mathematics': 9, 'Criminal Justice and Corrections.': 9, 'Statistics.': 1, 'Basic Computer Skills.': 2, 'History.': 7, 'Business, Management, and Related Support Services.': 44, 'Political Science, Government, International Relations and National Security Studies.': 3, 'Nursing': 3, 'English Language and Literature/Letters': 2, 'Chemistry.': 2, 'Psychology, General/Other.': 8, 'Communications and Media Studies, General/Other.': 3, 'Legal Professions and Studies.': 1, 'Computer and Information Sciences.': 11, 'Area, Ethnic, Cultural, Gender, and Group Studies, Other.': 1, 'Geological and Earth Sciences/Geosciences.': 1, 'Rhetoric and Composition/Writing Studies.': 17, 'Marketing.': 6, 'Education.': 3, 'Accounting and Related Services.': 4, 'Homeland Security.': 7, 'Job-Seeking and Career Skills': 6, 'Liberal Arts and Sciences, General Studies and Humanities.': 1, 'Philosophy.': 4, 'Anthropology.': 1, 'Japanese Language and Literature.': 1, 'Atmospheric Sciences and Meteorology.': 1, 'Economics.': 2, 'Natural Resources and Conservation.': 2, 'Speech Communication and Rhetoric.': 1, 'Foods, Nutrition, and Related Services.': 2, 'Spanish Language and Literature.': 2, 'Sociology': 3, 'Library Science.': 1, 'Journalism.': 2, 'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Military Science, Leadership, Operational Art, Applied Science, and Technologies': 1, 'Engineering.': 1},
#  ('University of Florida', 2005): {'History.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Business, Management, and Related Support Services.': 1},
#  ('Laredo Community College', 2012): {'Criminal Justice and Corrections.': 2,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 1,
#   'Basic Computer Skills.': 1,
#   'Mechanic and Repair Technologies/Technicians.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1},
#  ('The University of Texas at San Antonio',
#   2018): {'Business, Management, and Related Support Services.': 1, 'Computer and Information Sciences.': 2, 'English Language and Literature/Letters': 1, 'Music.': 1, 'Criminal Justice and Corrections.': 1, 'Economics.': 1, 'Engineering.': 2},
#  ('Valencia College', 2012): {'Chemistry.': 1,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 1},
#  ('Bellevue College',
#   2017): {'Business, Management, and Related Support Services.': 1, 'Rhetoric and Composition/Writing Studies.': 3, 'English Language and Literature/Letters': 1, 'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Psychology, General/Other.': 1},
#  ('Texas A & M International University',
#   2015): {'Criminal Justice and Corrections.': 1, 'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Dance.': 1},
#  ('The University of Texas at Tyler',
#   2007): {'Biological and Biomedical Sciences, General/Other.': 2, 'Speech Communication and Rhetoric.': 1, 'Psychology, General/Other.': 1, 'Engineering.': 1},
#  ('Northwest College', 2020): {'English Language and Literature/Letters': 1},
#  ('Tyler Junior College', 2017): {'Basic Computer Skills.': 3,
#   'Fire Protection.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 3,
#   'Rhetoric and Composition/Writing Studies.': 4,
#   'Psychology, General/Other.': 2,
#   'Fine and Studio Arts.': 2,
#   'Mathematics/Applied Mathematics': 2,
#   'Health and Medical Administrative Services.': 1,
#   'Music.': 2,
#   'Communications and Media Studies, General/Other.': 1,
#   'Anatomy.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 1,
#   'Drama/Theatre Arts and Stagecraft.': 1,
#   'Nursing': 2,
#   'Religion/Religious Studies.': 1,
#   'Speech Communication and Rhetoric.': 1},
#  ('University of Illinois at Chicago',
#   2014): {'Business, Management, and Related Support Services.': 2, 'Accounting and Related Services.': 1, 'Computer and Information Sciences.': 1},
#  ('Bellevue College', 2015): {'English Language and Literature/Letters': 2,
#   'Basic Skills and Developmental/Remedial/High School Level Education': 4,
#   'Business, Management, and Related Support Services.': 1},
#  ('Wilkes University', 2010): {'Rhetoric and Composition/Writing Studies.': 2},
#  ('Skidmore College', 2006): {'Film/Video and Photographic Arts.': 1},
#  ('Excelsior College', 2013): {'Criminal Justice and Corrections.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Nursing': 2,
#   'Liberal Arts and Sciences, General Studies and Humanities.': 2,
#   'Military Science, Leadership, Operational Art, Applied Science, and Technologies': 1},
#  ('University of Evansville', 2016): {'Psychology, General/Other.': 1,
#   'Computer and Information Sciences.': 1},
#  ('Imperial Valley College', 2015): {'Psychology, General/Other.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Basic Computer Skills.': 1,
#   'Music.': 2,
#   'Rhetoric and Composition/Writing Studies.': 2,
#   'Sociology': 1},
#  ('University of Georgia', 2003): {'Design and Applied Arts.': 1},
#  ('Stephen F Austin State University', 2011): {'Journalism.': 1,
#   'Nursing': 2,
#   'Fine and Studio Arts.': 1,
#   'Music.': 1,
#   'English Language and Literature/Letters': 1,
#   'German Language and Literature.': 1,
#   'Education.': 1},
#  ('The University of Montana', 2016): {'Journalism.': 1},
#  ('University of Maryland-University College',
#   2016): {'Business, Management, and Related Support Services.': 38, 'Computer and Information Sciences.': 18, 'Biological and Biomedical Sciences, General/Other.': 8, 'Rhetoric and Composition/Writing Studies.': 16, 'Marketing.': 5, 'Basic Computer Skills.': 3, 'Education.': 5, 'Public Health.': 2, 'History.': 6, 'Job-Seeking and Career Skills': 5, 'Liberal Arts and Sciences, General Studies and Humanities.': 3, 'Computer, Network, and Technology Support Services.': 13, 'Military Science, Leadership, Operational Art, Applied Science, and Technologies': 1, 'Criminal Justice and Corrections.': 6, 'Sociology': 5, "Women's Studies.": 2, 'Speech Communication and Rhetoric.': 4, 'Psychology, General/Other.': 12, 'Economics.': 4, 'Communications and Media Studies, General/Other.': 2, 'Library Science.': 3, 'English Language and Literature/Letters': 2, 'Homeland Security.': 4, 'Social Work.': 2, 'Clinical, Counseling and Applied Psychology.': 1, 'Accounting and Related Services.': 4, 'Fine and Studio Arts.': 1, 'Natural Resources and Conservation.': 3, 'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Film/Video and Photographic Arts.': 4, 'Health and Medical Administrative Services.': 1, 'Nursing': 2, 'Health-related Knowledge and Skills.': 1, 'Mathematics/Applied Mathematics': 8, 'Japanese Language and Literature.': 1, 'Astronomy and Astrophysics.': 1, 'Political Science, Government, International Relations and National Security Studies.': 1, 'Engineering Technologies and Engineering-related Fields.': 1, 'Engineering.': 1, 'Geography and Cartography.': 1, 'Spanish Language and Literature.': 1, 'German Language and Literature.': 1, 'Journalism.': 1, 'Statistics.': 1},
#  ('Angelo State University', 2015): {'Job-Seeking and Career Skills': 1,
#   'Communications and Media Studies, General/Other.': 1,
#   'Speech Communication and Rhetoric.': 1,
#   'Basic Skills and Developmental/Remedial/High School Level Education': 1,
#   'English Language and Literature/Letters': 1,
#   'Research and Experimental Psychology.': 1,
#   'History.': 1,
#   'Psychology, General/Other.': 1,
#   'Fine and Studio Arts.': 2,
#   'Education.': 1},
#  ('Clemson University', 2014): {'Mathematics/Applied Mathematics': 3,
#   'Economics.': 1,
#   'Engineering.': 3,
#   'Spanish Language and Literature.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Statistics.': 1,
#   'English Language and Literature/Letters': 1,
#   'Education.': 1,
#   'Agriculture, Agriculture Operations, and Related Sciences.': 1,
#   'Drama/Theatre Arts and Stagecraft.': 1},
#  ('Northwest College', 2017): {'Physics.': 1,
#   'Music.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Education.': 1},
#  ('University of North Carolina at Charlotte',
#   2013): {'Accounting and Related Services.': 1, 'Business, Management, and Related Support Services.': 1},
#  ('University of Maryland-University College',
#   2014): {'Business, Management, and Related Support Services.': 17, 'Education.': 3, 'Criminal Justice and Corrections.': 5, 'Homeland Security.': 5, 'Rhetoric and Composition/Writing Studies.': 7, 'Anatomy.': 1, 'Computer and Information Sciences.': 4, 'Fine and Studio Arts.': 1, 'History.': 4, 'Biological and Biomedical Sciences, General/Other.': 2, 'Spanish Language and Literature.': 1, 'Computer, Network, and Technology Support Services.': 1, 'Second Language Learning.': 1, 'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Engineering.': 2, 'Accounting and Related Services.': 2, 'Mathematics/Applied Mathematics': 1, 'Psychology, General/Other.': 3, 'Speech Communication and Rhetoric.': 1, 'English Language and Literature/Letters': 3, 'Liberal Arts and Sciences, General Studies and Humanities.': 1, 'Natural Resources and Conservation.': 2, 'Economics.': 2, 'Communications and Media Studies, General/Other.': 1, 'Political Science, Government, International Relations and National Security Studies.': 1, 'Health and Medical Administrative Services.': 1, 'Library Science.': 2, 'Criminology.': 1},
#  ('Loyola University New Orleans', 2012): {'Legal Professions and Studies.': 2,
#   'Philosophy.': 2,
#   'Anthropology.': 2},
#  ('Sam Houston State University',
#   2015): {'Computer and Information Sciences.': 1, 'Clinical, Counseling and Applied Psychology.': 1, 'Geography and Cartography.': 1, 'Agriculture, Agriculture Operations, and Related Sciences.': 1, 'Rhetoric and Composition/Writing Studies.': 3, 'Economics.': 1, 'Education.': 2, 'Business, Management, and Related Support Services.': 1, 'Criminal Justice and Corrections.': 3, 'Mathematics/Applied Mathematics': 1, 'Parks, Recreation, Leisure, and Fitness Studies.': 1, 'Culinary Arts and Related Services.': 1, 'Sociology': 1},
#  ('Northwest College',
#   2009): {'Parks, Recreation, Leisure, and Fitness Studies.': 1},
#  ('Park University', 2015): {'English Language and Literature/Letters': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 3,
#   'Accounting and Related Services.': 1,
#   'Business, Management, and Related Support Services.': 3,
#   'Mathematics/Applied Mathematics': 1,
#   'Statistics.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Basic Computer Skills.': 1},
#  ('Woodbury University',
#   2014): {'Communications and Media Studies, General/Other.': 2, 'Rhetoric and Composition/Writing Studies.': 1, 'Film/Video and Photographic Arts.': 1},
#  ('University of Southern California', 2011): {'Economics.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Architecture and Related Services.': 1},
#  ('Excelsior College', 2015): {'Criminal Justice and Corrections.': 1,
#   'Business, Management, and Related Support Services.': 6,
#   'Computer, Network, and Technology Support Services.': 4,
#   'Job-Seeking and Career Skills': 1,
#   'Natural Resources and Conservation.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Psychology, General/Other.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'History.': 1,
#   'Sociology': 1,
#   'Economics.': 1,
#   'Spanish Language and Literature.': 1},
#  ('University of North Texas',
#   2013): {'Communications and Media Studies, General/Other.': 1, 'English Language and Literature/Letters': 1, 'Sociology': 1, 'Music.': 1, 'Engineering.': 1, 'Business, Management, and Related Support Services.': 1, 'Psychology, General/Other.': 1, 'Dance.': 1, 'Parks, Recreation, Leisure, and Fitness Studies.': 1},
#  ('Texas State University', 2015): {'History.': 1,
#   'Economics.': 1,
#   'Spanish Language and Literature.': 1,
#   'Drama/Theatre Arts and Stagecraft.': 1,
#   'Sociology': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Architecture and Related Services.': 1,
#   'Communication Disorders Sciences and Services.': 1,
#   'Communications and Media Studies, General/Other.': 1},
#  ('The University of Texas at Austin', 2009): {'History.': 1,
#   'Communication Disorders Sciences and Services.': 1},
#  ('University of Arizona', 2005): {'Sociology': 1},
#  ('Oakton Community College',
#   2018): {'Allied Health Diagnostic, Intervention, and Treatment Professions.': 1},
#  ('University of Akron Main Campus',
#   2012): {'Drama/Theatre Arts and Stagecraft.': 1,
#   'Chemistry.': 2,
#   'Speech Communication and Rhetoric.': 1,
#   'Health and Medical Administrative Services.': 1},
#  ('Azusa Pacific University', 2016): {'Psychology, General/Other.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Education.': 2,
#   'Chemistry.': 1,
#   'Basic Computer Skills.': 1},
#  ('University of California-San Diego',
#   2015): {'Religion/Religious Studies.': 1, 'Computer and Information Sciences.': 1},
#  ('University of California-Irvine', 2009): {'Anthropology.': 1,
#   'Engineering.': 2,
#   'Sociology': 1,
#   'Mathematics/Applied Mathematics': 3,
#   'Physics.': 1,
#   'Computer and Information Sciences.': 2,
#   'Fine and Studio Arts.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Spanish Language and Literature.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1},
#  ('University of North Texas', 2012): {'Social Work.': 1,
#   'Business, Management, and Related Support Services.': 2,
#   'Mathematics/Applied Mathematics': 1,
#   'Rhetoric and Composition/Writing Studies.': 2,
#   'Accounting and Related Services.': 1,
#   'Education.': 1,
#   'Psychology, General/Other.': 1,
#   'Computer and Information Sciences.': 2,
#   'Fine and Studio Arts.': 1,
#   'Economics.': 1,
#   'Music.': 1,
#   'Engineering.': 2,
#   'Philosophy.': 1,
#   'Sociology': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1},
#  ('The University of Texas at Dallas',
#   2012): {'Business, Management, and Related Support Services.': 3, 'History.': 1, 'Film/Video and Photographic Arts.': 1, 'Fine and Studio Arts.': 1, 'Computer and Information Sciences.': 2, 'Accounting and Related Services.': 1, 'Engineering.': 2, 'Criminal Justice and Corrections.': 1, 'English Language and Literature/Letters': 1, 'Biological and Biomedical Sciences, General/Other.': 2},
#  ('Virginia Commonwealth University',
#   2009): {'Mathematics/Applied Mathematics': 1},
#  ('Sam Houston State University',
#   2014): {'Geological and Earth Sciences/Geosciences.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Agriculture, Agriculture Operations, and Related Sciences.': 1,
#   'Psychology, General/Other.': 1,
#   'English Language and Literature/Letters': 1,
#   'Sociology': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Foods, Nutrition, and Related Services.': 1},
#  ('Lansing Community College',
#   2017): {'Basic Skills and Developmental/Remedial/High School Level Education': 3, 'Computer and Information Sciences.': 3, 'Mechanic and Repair Technologies/Technicians.': 1, 'Allied Health Diagnostic, Intervention, and Treatment Professions.': 4, 'Chemistry.': 2, 'Parks, Recreation, Leisure, and Fitness Studies.': 2, 'English Language and Literature/Letters': 1, 'Computer, Network, and Technology Support Services.': 1, 'Health and Medical Administrative Services.': 1, 'Construction Trades.': 2, 'Natural Resources and Conservation.': 1, 'Business, Management, and Related Support Services.': 6, 'Rhetoric and Composition/Writing Studies.': 2, 'Mathematics/Applied Mathematics': 2, 'American Sign Language.': 1, 'Basic Computer Skills.': 2, 'Criminal Justice and Corrections.': 3, 'Fine and Studio Arts.': 2, 'Spanish Language and Literature.': 1, 'Anatomy.': 1, 'Sociology': 1, 'Marketing.': 1, 'Legal Professions and Studies.': 1, 'Economics.': 1, 'History.': 1, 'Political Science, Government, International Relations and National Security Studies.': 1, 'Foods, Nutrition, and Related Services.': 1, 'Education.': 1},
#  ('Oberlin College', 2006): {'Film/Video and Photographic Arts.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1},
#  ('The University of Texas at Dallas', 2010): {'Geography and Cartography.': 1,
#   'Accounting and Related Services.': 3,
#   'History.': 1,
#   'Computer and Information Sciences.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1},
#  ('Southern Utah University',
#   2005): {'Biological and Biomedical Sciences, General/Other.': 1},
#  ('McLennan Community College',
#   2012): {'Political Science, Government, International Relations and National Security Studies.': 2,
#   'American Sign Language.': 1,
#   'Medicine and Health Professions, General': 1,
#   'Business, Management, and Related Support Services.': 2,
#   'Rhetoric and Composition/Writing Studies.': 2,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Basic Computer Skills.': 1,
#   'Anthropology.': 1,
#   'History.': 1,
#   'Criminal Justice and Corrections.': 1},
#  ('Imperial Valley College',
#   2018): {'Communications and Media Studies, General/Other.': 1},
#  ('University of Scranton', 2004): {'Chemistry.': 1},
#  ('Amarillo College',
#   2016): {'Allied Health Diagnostic, Intervention, and Treatment Professions.': 2,
#   'Architecture and Related Services.': 1,
#   'Statistics.': 1,
#   'Spanish Language and Literature.': 1,
#   'History.': 1,
#   'Basic Skills and Developmental/Remedial/High School Level Education': 2,
#   'Biological and Biomedical Sciences, General/Other.': 2,
#   'Mechanic and Repair Technologies/Technicians.': 2,
#   'Engineering Technologies and Engineering-related Fields.': 1,
#   'Mathematics/Applied Mathematics': 3,
#   'Business, Management, and Related Support Services.': 1,
#   'Film/Video and Photographic Arts.': 1,
#   'English Language and Literature/Letters': 2,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Health and Medical Administrative Services.': 1,
#   'Nursing': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 3,
#   'Basic Computer Skills.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Speech Communication and Rhetoric.': 2},
#  ('University of South Florida-Main Campus',
#   2007): {'Business, Management, and Related Support Services.': 1, 'Social Work.': 1},
#  ('Lassen Community College',
#   2013): {'Parks, Recreation, Leisure, and Fitness Studies.': 1},
#  ('South Plains College',
#   2015): {'Engineering Technologies and Engineering-related Fields.': 1,
#   'Agriculture, Agriculture Operations, and Related Sciences.': 1,
#   'History.': 1,
#   'Psychology, General/Other.': 1,
#   'Mechanic and Repair Technologies/Technicians.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Nursing': 1},
#  ('Villanova University', 2003): {'Economics.': 1, 'History.': 1},
#  ('Excelsior College',
#   2010): {'Military Science, Leadership, Operational Art, Applied Science, and Technologies': 1, 'Psychology, General/Other.': 1},
#  ('Technical College of the Lowcountry', 2017): {'Nursing': 1,
#   'Criminal Justice and Corrections.': 1},
#  ('Lansing Community College', 2013): {'Nursing': 1,
#   'Computer and Information Sciences.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 2,
#   'Speech Communication and Rhetoric.': 1,
#   'Natural Resources and Conservation.': 1,
#   'Criminal Justice and Corrections.': 1,
#   'Accounting and Related Services.': 1,
#   'Basic Skills and Developmental/Remedial/High School Level Education': 2,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Fine and Studio Arts.': 2,
#   'Business, Management, and Related Support Services.': 2,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 1},
#  ('New Mexico Junior College', 2011): {'Psychology, General/Other.': 1,
#   'Social Work.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 1,
#   'English Language and Literature/Letters': 1},
#  ('Lansing Community College', 2015): {'Fine and Studio Arts.': 4,
#   'Film/Video and Photographic Arts.': 3,
#   'Psychology, General/Other.': 2,
#   'Business, Management, and Related Support Services.': 5,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 6,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 2,
#   'German Language and Literature.': 1,
#   'Geography and Cartography.': 2,
#   'Biological and Biomedical Sciences, General/Other.': 2,
#   'Drama/Theatre Arts and Stagecraft.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 2,
#   'Music.': 2,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Medicine and Health Professions, General': 2,
#   'Accounting and Related Services.': 1,
#   'Basic Skills and Developmental/Remedial/High School Level Education': 6,
#   'Education.': 2,
#   'Natural Resources and Conservation.': 1,
#   'Mathematics/Applied Mathematics': 6,
#   'English Language and Literature/Letters': 5,
#   'Anatomy.': 1,
#   'Chinese Language and Literature.': 1,
#   'Computer and Information Sciences.': 1,
#   'Spanish Language and Literature.': 2,
#   'Mechanic and Repair Technologies/Technicians.': 1,
#   'Construction Trades.': 1,
#   'American Sign Language.': 2,
#   'Religion/Religious Studies.': 2,
#   'Chemistry.': 2,
#   'Military Science, Leadership, Operational Art, Applied Science, and Technologies': 1,
#   'Basic Computer Skills.': 1,
#   'Sociology': 1,
#   'Computer, Network, and Technology Support Services.': 1,
#   'Fire Protection.': 1},
#  ('George Mason University', 2009): {'Education.': 2,
#   'Computer and Information Sciences.': 1},
#  ('University of Georgia', 2017): {'Economics.': 1,
#   'Natural Resources and Conservation.': 2,
#   'Education.': 1},
#  ('West Texas A & M University', 2018): {'Mathematics/Applied Mathematics': 1,
#   'English Language and Literature/Letters': 1,
#   'Communications and Media Studies, General/Other.': 1},
#  ('Clark State Community College', 2013): {'Psychology, General/Other.': 1,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Film/Video and Photographic Arts.': 1,
#   'Speech Communication and Rhetoric.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Agriculture, Agriculture Operations, and Related Sciences.': 1},
#  ('University of Illinois at Urbana-Champaign', 2018): {'Physics.': 3},
#  ('Bennington College', 2008): {'History.': 1},
#  ('Lewis and Clark Community College', 2017): {'Construction Trades.': 1,
#   'Health and Medical Administrative Services.': 1,
#   'Business, Management, and Related Support Services.': 1},
#  ('Oakton Community College',
#   2004): {'Basic Skills and Developmental/Remedial/High School Level Education': 1},
#  ('Western Kentucky University',
#   2015): {'Communications and Media Studies, General/Other.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 2,
#   'Philosophy.': 1,
#   'Nursing': 2,
#   'Education.': 2,
#   'English Language and Literature/Letters': 1,
#   'French Language and Literature.': 2,
#   'Mathematics/Applied Mathematics': 3,
#   'Chemistry.': 1,
#   'Dance.': 1,
#   'Computer and Information Sciences.': 1,
#   'Fine and Studio Arts.': 1},
#  ('Midwestern State University', 2011): {'Nursing': 7,
#   'Rhetoric and Composition/Writing Studies.': 2,
#   'English Language and Literature/Letters': 1,
#   'Psychology, General/Other.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Fine and Studio Arts.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Basic Computer Skills.': 1},
#  ('Bellevue College', 2007): {'Economics.': 1},
#  ('Columbia University in the City of New York', 2005): {'Journalism.': 1},
#  ('Amarillo College',
#   2011): {'Biological and Biomedical Sciences, General/Other.': 1, 'Basic Computer Skills.': 3, 'Anatomy.': 1, 'Business, Management, and Related Support Services.': 1, 'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Mathematics/Applied Mathematics': 2, 'Psychology, General/Other.': 1},
#  ('Amarillo College', 2013): {'English Language and Literature/Letters': 4,
#   'Rhetoric and Composition/Writing Studies.': 3,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 1,
#   'Engineering.': 1,
#   'Basic Computer Skills.': 3,
#   'Basic Skills and Developmental/Remedial/High School Level Education': 1,
#   'Engineering Technologies and Engineering-related Fields.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'History.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1},
#  ('Johns Hopkins University', 2006): {'Computer and Information Sciences.': 1,
#   'Mathematics/Applied Mathematics': 1},
#  ('Illinois State University',
#   2009): {'Communications and Media Studies, General/Other.': 1, 'Business, Management, and Related Support Services.': 1},
#  ('Alvin Community College',
#   2015): {'Rhetoric and Composition/Writing Studies.': 1},
#  ('Palm Beach State College',
#   2018): {'English Language and Literature/Letters': 10,
#   'Health and Medical Administrative Services.': 2,
#   'Anatomy.': 2,
#   'Spanish Language and Literature.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Basic Computer Skills.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Mechanic and Repair Technologies/Technicians.': 1,
#   'Fine and Studio Arts.': 2,
#   'Mathematics/Applied Mathematics': 2,
#   'Dentistry': 1,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Business, Management, and Related Support Services.': 1},
#  ('Stephen F Austin State University',
#   2017): {'Political Science, Government, International Relations and National Security Studies.': 1, 'Parks, Recreation, Leisure, and Fitness Studies.': 1, 'Mathematics/Applied Mathematics': 2, 'Fine and Studio Arts.': 1, 'Communications and Media Studies, General/Other.': 1, 'Criminal Justice and Corrections.': 1, 'Astronomy and Astrophysics.': 1, 'Biological and Biomedical Sciences, General/Other.': 1, 'Social Work.': 1, 'English Language and Literature/Letters': 1, 'Psychology, General/Other.': 1, 'Accounting and Related Services.': 1, 'Rhetoric and Composition/Writing Studies.': 1, 'Philosophy.': 1},
#  ('Palm Beach State College',
#   2017): {'Rhetoric and Composition/Writing Studies.': 2, 'Education.': 2, 'Social Work.': 1, 'English Language and Literature/Letters': 2, 'Nursing': 1, 'Speech Communication and Rhetoric.': 1, 'Mathematics/Applied Mathematics': 1, 'Biological and Biomedical Sciences, General/Other.': 2, 'Fine and Studio Arts.': 1, 'Political Science, Government, International Relations and National Security Studies.': 1, 'Anatomy.': 1, 'Basic Computer Skills.': 1, 'Economics.': 1, 'Computer and Information Sciences.': 1},
#  ('Jones County Junior College', 2016): {'History.': 1},
#  ('Clark State Community College',
#   2015): {'Business, Management, and Related Support Services.': 2, 'History.': 1, 'Nursing': 1, 'Biological and Biomedical Sciences, General/Other.': 1, 'Mathematics/Applied Mathematics': 1, 'Engineering Technologies and Engineering-related Fields.': 2, 'Philosophy.': 1, 'Speech Communication and Rhetoric.': 1},
#  ('University of Florida',
#   2014): {'Biological and Biomedical Sciences, General/Other.': 1, 'Chemistry.': 1},
#  ('Midland College', None): {'Spanish Language and Literature.': 1},
#  ('Clark State Community College', 2001): {'Fine and Studio Arts.': 3,
#   'Education.': 1,
#   'Computer and Information Sciences.': 1,
#   'Speech Communication and Rhetoric.': 1,
#   'Business, Management, and Related Support Services.': 1},
#  ('West Los Angeles College',
#   2017): {'English Language and Literature/Letters': 1, 'Biological and Biomedical Sciences, General/Other.': 2, 'Mathematics/Applied Mathematics': 1},
#  ('Galveston College', 2014): {'Rhetoric and Composition/Writing Studies.': 1,
#   'Anatomy.': 1,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 3,
#   'Culinary Arts and Related Services.': 1,
#   'Nursing': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Computer and Information Sciences.': 1},
#  ('Collin County Community College District',
#   2013): {'English Language and Literature/Letters': 3, 'Computer and Information Sciences.': 1, 'Spanish Language and Literature.': 1, 'Rhetoric and Composition/Writing Studies.': 1, 'Nursing': 1, 'History.': 1, 'Pharmacy, Pharmaceutical Sciences, and Administration.': 1, 'Music.': 2, 'Dance.': 1, 'Chemistry.': 1, 'Drama/Theatre Arts and Stagecraft.': 1, 'Political Science, Government, International Relations and National Security Studies.': 2, 'Film/Video and Photographic Arts.': 2, 'Sociology': 1, 'Philosophy.': 1, 'Mathematics/Applied Mathematics': 1},
#  ('Wright State University-Main Campus',
#   1999): {'English Language and Literature/Letters': 1},
#  ('University of Maryland-University College',
#   2018): {'Business, Management, and Related Support Services.': 10,
#   'Homeland Security.': 3,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Medicine and Health Professions, General': 1,
#   'Accounting and Related Services.': 2,
#   'History.': 1,
#   'Computer, Network, and Technology Support Services.': 6,
#   'Education.': 1,
#   'Rhetoric and Composition/Writing Studies.': 5,
#   'Criminal Justice and Corrections.': 2,
#   'Speech Communication and Rhetoric.': 1,
#   'Job-Seeking and Career Skills': 1,
#   'Legal Professions and Studies.': 1,
#   'Spanish Language and Literature.': 1,
#   'Statistics.': 1,
#   'English Language and Literature/Letters': 2,
#   'Mathematics/Applied Mathematics': 1,
#   'Communications and Media Studies, General/Other.': 1,
#   'Anatomy.': 1,
#   'Marketing.': 1,
#   'Computer and Information Sciences.': 1,
#   'Health and Medical Administrative Services.': 1},
#  ('The University of Texas at Dallas', 2016): {'Engineering.': 2,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Business, Management, and Related Support Services.': 2,
#   'Area, Ethnic, Cultural, Gender, and Group Studies, Other.': 1,
#   'Marketing.': 2,
#   'Fine and Studio Arts.': 1,
#   'Communications and Media Studies, General/Other.': 1,
#   'Accounting and Related Services.': 2,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1},
#  ('Clark State Community College',
#   2007): {'Accounting and Related Services.': 2, 'Education.': 1, 'Biological and Biomedical Sciences, General/Other.': 1, 'Business, Management, and Related Support Services.': 1},
#  ('University of California-Irvine',
#   2010): {'Computer and Information Sciences.': 2, 'Mathematics/Applied Mathematics': 1, 'Education.': 1, 'Liberal Arts and Sciences, General Studies and Humanities.': 1, 'History.': 1, 'Biological and Biomedical Sciences, General/Other.': 1, 'Physics.': 1},
#  ('George Mason University', 2013): {'Education.': 2,
#   'Legal Professions and Studies.': 2,
#   'Geography and Cartography.': 1,
#   'Accounting and Related Services.': 1,
#   'Computer and Information Sciences.': 1},
#  ('Park University', 2014): {'Education.': 1,
#   'Economics.': 1,
#   'Legal Professions and Studies.': 1,
#   'Psychology, General/Other.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Business, Management, and Related Support Services.': 2,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Criminal Justice and Corrections.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 3,
#   'Statistics.': 1,
#   'Marketing.': 1},
#  ('Goucher College', 2016): {'Computer and Information Sciences.': 1},
#  ('University of Florida', 2006): {'History.': 1,
#   'English Language and Literature/Letters': 1},
#  ('The University of Texas at Austin',
#   2014): {'English Language and Literature/Letters': 1, 'Social Work.': 1, 'Education.': 1, 'Computer and Information Sciences.': 1, 'Journalism.': 1, 'Engineering.': 1, 'Biological and Biomedical Sciences, General/Other.': 1},
#  ('Sam Houston State University',
#   2011): {'Criminal Justice and Corrections.': 1, 'Economics.': 1, 'Statistics.': 1, 'Education.': 2, 'Parks, Recreation, Leisure, and Fitness Studies.': 1, 'Rhetoric and Composition/Writing Studies.': 1, 'Business, Management, and Related Support Services.': 1, 'Communications and Media Studies, General/Other.': 1, 'Philosophy.': 1},
#  ('University of Wisconsin-Whitewater',
#   2001): {'Business, Management, and Related Support Services.': 1},
#  ('North Idaho College', 2014): {'Statistics.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 2,
#   'Basic Computer Skills.': 3,
#   'History.': 2,
#   'Anthropology.': 1,
#   'Sociology': 2,
#   'Marketing.': 1,
#   'Mathematics/Applied Mathematics': 7,
#   'Business, Management, and Related Support Services.': 3,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Dance.': 1,
#   'Construction Trades.': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 5,
#   'Engineering Technologies and Engineering-related Fields.': 2,
#   'Mechanic and Repair Technologies/Technicians.': 2,
#   'Nursing': 1,
#   'Fine and Studio Arts.': 2,
#   'Psychology, General/Other.': 2,
#   'Chemistry.': 1,
#   'Education.': 1,
#   'Physics.': 1},
#  ('Harding University',
# ...
#  ('Cerro Coso Community College', None): {'Astronomy and Astrophysics.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1},
#  ('University of Georgia', 2008): {'Architecture and Related Services.': 1,
#   'Computer and Information Sciences.': 1},
#  ('Sam Houston State University', 2012): {'Education.': 1,
#   'Fine and Studio Arts.': 1,
#   'Communications and Media Studies, General/Other.': 1,
#   'History.': 1},
#  ('Rio Salado College', 2017): {'Culinary Arts and Related Services.': 1,
#   'Psychology, General/Other.': 1,
#   'Foods, Nutrition, and Related Services.': 1},
#  ('Humboldt State University', 2011): {'Music.': 2},
#  ('Brookdale Community College', 2018): {'Nursing': 1},
#  ('University of Maryland-College Park',
#   2017): {'Political Science, Government, International Relations and National Security Studies.': 1, 'Computer and Information Sciences.': 1},
#  ('Angelina College', 2017): {'Statistics.': 1,
#   'Basic Computer Skills.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'English Language and Literature/Letters': 1,
#   'Rhetoric and Composition/Writing Studies.': 1},
#  ('New Mexico Junior College', 2012): {'Criminal Justice and Corrections.': 1,
#   'Job-Seeking and Career Skills': 1},
#  ('The University of Texas at Arlington',
#   2013): {'Computer and Information Sciences.': 3, 'Spanish Language and Literature.': 1, 'Nursing': 1, 'Business, Management, and Related Support Services.': 3, 'Parks, Recreation, Leisure, and Fitness Studies.': 1, 'Chemistry.': 1, 'Linguistics.': 1, 'Music.': 1},
#  ('Academy of Art University',
#   2004): {'Rhetoric and Composition/Writing Studies.': 1, 'Fine and Studio Arts.': 1},
#  ('Western Illinois University',
#   2017): {'English Language and Literature/Letters': 1, 'Education.': 1},
#  ('Loyola Marymount University',
#   2013): {'Political Science, Government, International Relations and National Security Studies.': 1},
#  ('University of Massachusetts-Boston',
#   2014): {'Psychology, General/Other.': 1, 'Computer and Information Sciences.': 1},
#  ('Santa Rosa Junior College', 2002): {'Basic Computer Skills.': 1},
#  ('Stony Brook University',
#   2017): {'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Marketing.': 1, 'Engineering.': 1, 'Computer and Information Sciences.': 1, 'French Language and Literature.': 1},
#  ('The University of Texas at Arlington', 2015): {'Anthropology.': 1,
#   'Architecture and Related Services.': 1,
#   'Communications and Media Studies, General/Other.': 1,
#   'Drama/Theatre Arts and Stagecraft.': 1,
#   'Spanish Language and Literature.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1,
#   'Basic Skills and Developmental/Remedial/High School Level Education': 1,
#   'Education.': 2,
#   'Economics.': 1,
#   'Music.': 1},
#  ('Loyola University Chicago', 2000): {'Religion/Religious Studies.': 1},
#  ('University of Northern Iowa',
#   2004): {'Computer and Information Sciences.': 1},
#  ('University of Arkansas at Little Rock', 2014): {'Social Work.': 1},
#  ('Angelo State University', 2016): {'Philosophy.': 1,
#   'Music.': 1,
#   'Mathematics/Applied Mathematics': 1},
#  ('The University of Tennessee-Martin', 1995): {'Marketing.': 1},
#  ('University of Utah', 2014): {'Speech Communication and Rhetoric.': 1},
#  ('McLennan Community College',
#   2016): {'Health and Medical Administrative Services.': 1, 'Computer and Information Sciences.': 1, 'Nursing': 2, 'Drama/Theatre Arts and Stagecraft.': 1, 'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Music.': 3, 'Psychology, General/Other.': 1, 'Fine and Studio Arts.': 1, 'Parks, Recreation, Leisure, and Fitness Studies.': 1},
#  ('Massachusetts Institute of Technology',
#   2006): {'Communications and Media Studies, General/Other.': 1, 'Mathematics/Applied Mathematics': 1},
#  ('SUNY at Albany',
#   2003): {'Political Science, Government, International Relations and National Security Studies.': 1},
#  ('California State University-Sacramento',
#   2017): {'French Language and Literature.': 1, 'Economics.': 1},
#  ('California Institute of Technology', 2009): {'Physics.': 1,
#   'Computer and Information Sciences.': 1},
#  ('Texas A & M University-College Station',
#   2018): {'Mathematics/Applied Mathematics': 1, 'Computer and Information Sciences.': 2, 'Engineering.': 1, 'Sociology': 1, 'Architecture and Related Services.': 1, 'Parks, Recreation, Leisure, and Fitness Studies.': 1, 'Chemistry.': 1, 'English Language and Literature/Letters': 1},
#  ('West Chester University of Pennsylvania',
#   None): {'English Language and Literature/Letters': 1},
#  ('Azusa Pacific University', 2012): {'Theology and Religious Vocations.': 1,
#   'Business, Management, and Related Support Services.': 1},
#  ('The University of Alabama',
#   2003): {'Foods, Nutrition, and Related Services.': 1},
#  ('Clayton State University',
#   2012): {'Biological and Biomedical Sciences, General/Other.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1},
#  ('Asbury Theological Seminary',
#   2005): {'Theology and Religious Vocations.': 1},
#  ('Rochester Institute of Technology',
#   2004): {'Computer and Information Sciences.': 1},
#  ('University of California-San Diego',
#   None): {'Political Science, Government, International Relations and National Security Studies.': 2,
#   'Education.': 1,
#   'Computer and Information Sciences.': 2},
#  ('El Paso Community College', 2016): {'Nursing': 1,
#   'Fine and Studio Arts.': 1,
#   'Music.': 1},
#  ('Jackson College', 2015): {'Speech Communication and Rhetoric.': 1},
#  ('Texas A & M University-College Station', 2003): {'Philosophy.': 1},
#  ('Shippensburg University of Pennsylvania', 2015): {'Education.': 1},
#  ('New Jersey Institute of Technology',
#   2014): {'Mathematics/Applied Mathematics': 1},
#  ('University of Washington-Seattle Campus',
#   2016): {'Computer and Information Sciences.': 1},
#  ('Kutztown University of Pennsylvania',
#   2015): {'Astronomy and Astrophysics.': 1},
#  ('George Mason University', 2017): {'Psychology, General/Other.': 1,
#   'Business, Management, and Related Support Services.': 2,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1,
#   'Mathematics/Applied Mathematics': 2,
#   'Health-related Knowledge and Skills.': 1},
#  ('University of Michigan-Ann Arbor',
#   2016): {'Geological and Earth Sciences/Geosciences.': 1, 'Statistics.': 1, 'Fine and Studio Arts.': 1, 'Social Work.': 1},
#  ('The University of Texas at San Antonio',
#   2014): {'Communications and Media Studies, General/Other.': 1, 'Business, Management, and Related Support Services.': 1, 'Education.': 1, 'Fine and Studio Arts.': 1, 'Political Science, Government, International Relations and National Security Studies.': 1, 'Biological and Biomedical Sciences, General/Other.': 1},
#  ('San Francisco State University', 2002): {'Engineering.': 1},
#  ('Rensselaer Polytechnic Institute',
#   2001): {'Computer and Information Sciences.': 1},
#  ('University of New Mexico-Main Campus', 2015): {'History.': 1},
#  ('University of Wisconsin-Oshkosh',
#   2013): {'Computer and Information Sciences.': 1,
#   'Business, Management, and Related Support Services.': 1},
#  ('Amarillo College', 2007): {'Anatomy.': 2,
#   'Rhetoric and Composition/Writing Studies.': 2,
#   'Mathematics/Applied Mathematics': 1,
#   'Basic Computer Skills.': 1},
#  ('Cerro Coso Community College',
#   2009): {'Parks, Recreation, Leisure, and Fitness Studies.': 1, 'Mathematics/Applied Mathematics': 1, 'Education.': 1},
#  ('Massachusetts Institute of Technology', 1985): {'Engineering.': 1},
#  ('University of Georgia', 2009): {'Mathematics/Applied Mathematics': 1,
#   'English Language and Literature/Letters': 1,
#   'Linguistics.': 1,
#   'Social Work.': 1,
#   'Education.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Psychology, General/Other.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1},
#  ('Illinois State University',
#   2013): {'Communications and Media Studies, General/Other.': 1, 'Speech Communication and Rhetoric.': 1, 'Social Work.': 1},
#  ('University of Massachusetts-Amherst', 2017): {'Economics.': 1},
#  ('Northwestern Connecticut Community College', 2012): {'History.': 1},
#  ('Texas A & M University-Commerce',
#   None): {'Architecture and Related Services.': 1, 'Fine and Studio Arts.': 1, 'Music.': 1},
#  ('University of Michigan-Ann Arbor',
#   2017): {'Biological and Biomedical Sciences, General/Other.': 2, 'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Fine and Studio Arts.': 1, 'Area, Ethnic, Cultural, Gender, and Group Studies, Other.': 1, 'Public Health.': 1},
#  ('Western Michigan University',
#   2004): {'Parks, Recreation, Leisure, and Fitness Studies.': 1, 'Political Science, Government, International Relations and National Security Studies.': 1, 'Music.': 1},
#  ('Great Basin College', 2008): {'Education.': 1,
#   'Marketing.': 1,
#   'Fine and Studio Arts.': 1,
#   'Allied Health Diagnostic, Intervention, and Treatment Professions.': 1,
#   'Sociology': 1},
#  ('Texarkana College', 2018): {'Education.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1},
#  ('Marist College', 2002): {'Computer and Information Sciences.': 1},
#  ('Wilkes University', 2000): {'Education.': 5},
#  ('Santa Ana College', None): {'Criminal Justice and Corrections.': 1},
#  ('CUNY Borough of Manhattan Community College',
#   None): {'Computer and Information Sciences.': 1},
#  ('Lansing Community College',
#   2018): {'Rhetoric and Composition/Writing Studies.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Legal Professions and Studies.': 1,
#   'Criminal Justice and Corrections.': 1},
#  ('El Paso Community College',
#   2014): {'Basic Skills and Developmental/Remedial/High School Level Education': 1, 'Foods, Nutrition, and Related Services.': 1},
#  ('Central Lakes College-Brainerd',
#   2014): {'English Language and Literature/Letters': 1, 'Fine and Studio Arts.': 1},
#  ('University of Florida',
#   2013): {'English Language and Literature/Letters': 1},
#  ('North Central Texas College', 2016): {'History.': 1,
#   'Rhetoric and Composition/Writing Studies.': 1},
#  ('Mount Wachusett Community College',
#   2011): {'Mechanic and Repair Technologies/Technicians.': 1},
#  ('Syracuse University',
#   2016): {'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Mathematics/Applied Mathematics': 1},
#  ('Stanford University', 2011): {'Computer and Information Sciences.': 1},
#  ('Houston Community College', 2006): {'Anatomy.': 1},
#  ('University of Maryland-College Park',
#   2016): {'Computer and Information Sciences.': 2, 'Engineering.': 1, 'Biological and Biomedical Sciences, General/Other.': 1},
#  ('San Juan College', 1990): {'Nursing': 1},
#  ('Edinboro University of Pennsylvania', 2011): {'Basic Computer Skills.': 1},
#  ('Princeton University', 2005): {'Engineering.': 1},
#  ('University of Denver', 2011): {'Legal Professions and Studies.': 1,
#   'Computer and Information Sciences.': 1},
#  ('Eastern Oregon University',
#   2002): {'Computer and Information Sciences.': 1},
#  ('Clark State Community College',
#   2018): {'Speech Communication and Rhetoric.': 1, 'Mathematics/Applied Mathematics': 1},
#  ('Westmont College', 2006): {'Psychology, General/Other.': 1},
#  ('SUNY College at Geneseo',
#   2011): {'English Language and Literature/Letters': 1},
#  ('The University of Texas at Austin', 2003): {'Statistics.': 1,
#   'Philosophy.': 1},
#  ('Boise State University',
#   2016): {'Communications and Media Studies, General/Other.': 1, 'Mathematics/Applied Mathematics': 1, 'Anthropology.': 1, 'Economics.': 1},
#  ('Loyola University New Orleans',
#   2009): {'Political Science, Government, International Relations and National Security Studies.': 1, 'Film/Video and Photographic Arts.': 1, 'Drama/Theatre Arts and Stagecraft.': 1, 'Religion/Religious Studies.': 1, 'Criminal Justice and Corrections.': 1},
#  ('Princeton University', 2017): {'Mathematics/Applied Mathematics': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Liberal Arts and Sciences, General Studies and Humanities.': 1},
#  ('University of Denver', 2009): {'Anthropology.': 1},
#  ('University of North Carolina at Greensboro',
#   2010): {'Rhetoric and Composition/Writing Studies.': 1},
#  ('University of Minnesota-Crookston',
#   2014): {'Business, Management, and Related Support Services.': 1},
#  ('Imperial Valley College', 2016): {'Fine and Studio Arts.': 2,
#   'Mathematics/Applied Mathematics': 1,
#   'French Language and Literature.': 1,
#   'Basic Skills and Developmental/Remedial/High School Level Education': 1,
#   'Parks, Recreation, Leisure, and Fitness Studies.': 1},
#  ('SUNY at Albany',
#   2009): {'Political Science, Government, International Relations and National Security Studies.': 1},
#  ('San Jose State University', 2009): {'Fine and Studio Arts.': 1,
#   'Library Science.': 2},
#  ('CUNY Borough of Manhattan Community College',
#   2017): {'English Language and Literature/Letters': 1},
#  ('Bossier Parish Community College', 2017): {'Music.': 1,
#   'Communications and Media Studies, General/Other.': 1},
#  ('University of North Carolina Wilmington', 2017): {'Social Work.': 1},
#  ('Coastal Bend College',
#   2013): {'Biological and Biomedical Sciences, General/Other.': 1},
#  ('University of North Carolina at Chapel Hill', 2017): {'Journalism.': 1,
#   'Computer and Information Sciences.': 1,
#   'Social Work.': 1},
#  ('George Mason University', 2006): {'Psychology, General/Other.': 1,
#   'Education.': 1},
#  ('University of Kansas',
#   2007): {'English Language and Literature/Letters': 1},
#  ('Woodbury University',
#   2018): {'Business, Management, and Related Support Services.': 1, 'Architecture and Related Services.': 1},
#  ('Davidson College', 1999): {'Economics.': 1},
#  ('Worcester Polytechnic Institute',
#   2007): {'Computer and Information Sciences.': 1},
#  ('University of Florida', 2002): {'Linguistics.': 1,
#   'Engineering.': 1,
#   'Film/Video and Photographic Arts.': 1},
#  ('Columbus State Community College',
#   None): {'Mechanic and Repair Technologies/Technicians.': 1},
#  ('Cape Cod Community College', 2015): {'Marketing.': 1,
#   'Fine and Studio Arts.': 1},
#  ('Northwest Florida State College',
#   1999): {'Parks, Recreation, Leisure, and Fitness Studies.': 1},
#  ('University of California-Berkeley',
#   2016): {'Legal Professions and Studies.': 1,
#   'Architecture and Related Services.': 1,
#   'History.': 1},
#  ('Catawba College', 2016): {'Accounting and Related Services.': 1},
#  ('Princeton University', None): {'Engineering.': 2},
#  ('Duke University', 2005): {'Legal Professions and Studies.': 1},
#  ('Minnesota State University Moorhead',
#   None): {'Mathematics/Applied Mathematics': 2},
#  ('Great Basin College',
#   2012): {'Health and Medical Administrative Services.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Business, Management, and Related Support Services.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 1},
#  ('Duke University',
#   2009): {'Classics and Classical Languages, Literatures, and Linguistics.': 1},
#  ('Ithaca College', 2004): {'Computer and Information Sciences.': 1},
#  ('Colorado Mesa University',
#   None): {'Basic Skills and Developmental/Remedial/High School Level Education': 1,
#   'Basic Computer Skills.': 1},
#  ('South Texas College', 2015): {'American Sign Language.': 1,
#   'Nursing': 1,
#   'Basic Computer Skills.': 1,
#   'Accounting and Related Services.': 1,
#   'Engineering Technologies and Engineering-related Fields.': 1,
#   'Mathematics/Applied Mathematics': 1,
#   'Mechanic and Repair Technologies/Technicians.': 1,
#   'Political Science, Government, International Relations and National Security Studies.': 1,
#   'Biological and Biomedical Sciences, General/Other.': 1,
#   'Business, Management, and Related Support Services.': 1},
#  ('Texas A & M University-Corpus Christi',
#   2003): {'Rhetoric and Composition/Writing Studies.': 1},
#  ('Santa Monica College', 2006): {'Mathematics/Applied Mathematics': 2},
#  ...}

# %%
import spacy

# %%
nlp = spacy.load("en")

# %%
for stopword in my_stop_words:
    lexeme = nlp.vocab[stopword]
    lexeme.is_stop = True

# %%
def clean_text(text, max_len=1500000):
    nlp.max_length = max_len
    if len(text) > max_len:
        text = text[0:max_len]
    doc = nlp(text.lower(), disable=["parser", "tagger", "ner"])
    clean_text = []
    for w in doc:
        if (not '\n' in w.text and not w.is_stop and not w.is_punct and not w.like_num and not '’' in w.text 
            and not ')' in w.text and not '\xa0' in w.text and not '\r' in w.text and not '\t' in w.text 
            and not '\v' in w.text and len(w.text) > 3 and "@" not in w.text and "https" not in w.text
            and w.lemma_ not in my_stop_words):
                # we add the lematized version of the word
                clean_text.append(w.lemma_)
    return clean_text

# %%
cleaned_texts = []

# %%
for text in texts:
    cleaned_texts.append(clean_text(text))

# %%
word_count = {}

# %%
for text in cleaned_texts:
    for word in text:
        if word not in word_count:
            word_count[word] = 0
        if word in word_count:
            word_count[word] += 1

# %%
import operator
sorted_words = sorted(word_count.items(), key=operator.itemgetter(1))

# %%
sorted_words.reverse()

# %%
for word_ in sorted_words[:100]:
    word, n = word_
    print(word, end=' ')
# Out:
# policy information program research state design plan social change analysis case development community computer content science demonstrate communication management code responsibility technology business source identify concept standard health method procedure professional knowledge high describe objective application theory area datum word cover member session completion spring idea personal specific history behavior order library performance graduate allow type human document attend opportunity numb critical subject address possible language current develop american answer environment participate internet principle view module year statement value function request evaluate field consider create build format record tool goal life strategy link prior advance account example world website select
